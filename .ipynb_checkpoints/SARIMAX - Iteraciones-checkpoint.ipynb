# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore", category=pd.errors.SettingWithCopyWarning)

# %%
#Importar Dataframe que contiene el trabajo semanal en la linea de volúmenes
df_vols_trabajo_semanal = pd.read_excel('./dataframes/df_vols_trabajo_semanal.xlsx')

# %%
#Preparar dataset
df_sarima = df_vols_trabajo_semanal.rename(columns={"semana_primer_dia": "ds", "tiempo_trabajo_horas": "y"})
df_sarima = df_sarima.drop(['semana', 'cantidad_fabricada', 'tiempo_trabajo', 'Unnamed: 0'], axis=1)

#Predeciremos 4 meses (16 semanaas, por tanto se testean 16 semanas)
fecha_max = df_vols_trabajo_semanal['semana_primer_dia'].max()
fecha_limite = fecha_max - pd.Timedelta(weeks = 15)
df_sarima_train = df_sarima[df_sarima['ds'] < pd.to_datetime(fecha_limite)]
df_sarima_test = df_sarima[df_sarima['ds'] >= pd.to_datetime(fecha_limite)]

print('Cantidad datos entrenamiento: ' + str(len(df_sarima_train)))
print('Cantidad datos test: ' + str(len(df_sarima_test)))
# Out:
# Cantidad datos entrenamiento: 169
# Cantidad datos test: 16

# %% [markdown]
# ## Ajuste iterativo de hiperparámetros

# %%
import warnings
from statsmodels.tsa.statespace.sarimax import SARIMAX
from joblib import Parallel, delayed
import pandas as pd
from sklearn.metrics import mean_squared_error

# Paralelizamos el ajuste de hiperparámetros para el modelo SARIMAX
# ITERATE = True  # Activar la iteración paralelizada
ITERATE = True  # Activar la iteración paralelizada

def adjust_model(order_input, seasonal_order_input):
    try:
        with warnings.catch_warnings(record=True) as w:
            warnings.simplefilter("always")
            
            # Ajuste del modelo SARIMA
            forecaster = SARIMAX(
                df_sarima_train['y'], 
                order=order_input, 
                seasonal_order=seasonal_order_input, 
                trend=None,
                enforce_stationarity=False,
                enforce_invertibility=False
            )
            
            # Intento de ajuste
            results = forecaster.fit(maxiter=10000)
            
            # Verificar si hubo advertencias como no convergencia
            # if any("ConvergenceWarning" in str(warning.message) or 
            #        "Too few observations" in str(warning.message) 
            #        for warning in w):
            #     print(f"Advertencia en la combinación Order: {order_input}, Seasonal Order: {seasonal_order_input}. Ignorado.")
            #     return order_input, seasonal_order_input, float("inf")
            
            # Predicción y cálculo del error si no hay advertencias
            y_pred_sarima = results.get_forecast(steps=16).predicted_mean
            data = {'ds': df_sarima_test['ds'], 'yhat': y_pred_sarima}
            y_pred_sarima = pd.DataFrame(data)
            
            rmse = mean_squared_error(df_sarima_test['y'], y_pred_sarima['yhat']) ** 0.5
            print(f"Order: {order_input}, Seasonal Order: {seasonal_order_input}, RMSE: {rmse}")
        
    except Exception as e:
        print(f"Error en Order: {order_input}, Seasonal Order: {seasonal_order_input} - {e}")
        rmse = float("inf")

    return order_input, seasonal_order_input, rmse

# Definir grid de búsqueda para los hiperparámetros
# rp, rd, rq = 3, 2, 3
# rP, rD, rQ, rS = 3, 2, 3, 52

rp, rd, rq = 4, 3, 5
rP, rD, rQ, rS = 3, 3, 3, 52

pdq = [(p, d, q) for p in range(rp) for d in range(rd) for q in range(rq)]
seasonal_pdq = [(P, D, Q, rS) for P in range(rP) for D in range(rD) for Q in range(rQ)]

# Iterar de manera paralelizada para buscar los hiperparámetros que minimizan el RMSE para el dataset.
if ITERATE:
    results = []
    for order in pdq:
        for seasonal_order in seasonal_pdq:
            result = adjust_model(order, seasonal_order)
            results.append(result)
# Out:
# Order: (0, 0, 0), Seasonal Order: (0, 0, 0, 52), RMSE: 23.915808441113647
# Order: (0, 0, 0), Seasonal Order: (0, 0, 1, 52), RMSE: 23.915808441113303
# Order: (0, 0, 0), Seasonal Order: (0, 0, 2, 52), RMSE: 6.50804372788093
# Order: (0, 0, 0), Seasonal Order: (0, 1, 0, 52), RMSE: 9.28751699956131
# Order: (0, 0, 0), Seasonal Order: (0, 1, 1, 52), RMSE: 10.812599677175713
# Order: (0, 0, 0), Seasonal Order: (0, 1, 2, 52), RMSE: 11.588342216580713
# Order: (0, 0, 0), Seasonal Order: (0, 2, 0, 52), RMSE: 10.982317736664482
# Order: (0, 0, 0), Seasonal Order: (0, 2, 1, 52), RMSE: 11.111546529144036
# Order: (0, 0, 0), Seasonal Order: (0, 2, 2, 52), RMSE: 10.982317736661049
# Order: (0, 0, 0), Seasonal Order: (1, 0, 0, 52), RMSE: 7.682264830125059
# Order: (0, 0, 0), Seasonal Order: (1, 0, 1, 52), RMSE: 6.390060949056532
# Order: (0, 0, 0), Seasonal Order: (1, 0, 2, 52), RMSE: 7.072955340717647
# Order: (0, 0, 0), Seasonal Order: (1, 1, 0, 52), RMSE: 10.704925819409072
# Order: (0, 0, 0), Seasonal Order: (1, 1, 1, 52), RMSE: 11.987185481750792
# Order: (0, 0, 0), Seasonal Order: (1, 1, 2, 52), RMSE: 14.494514831473307
# Order: (0, 0, 0), Seasonal Order: (1, 2, 0, 52), RMSE: 11.035104314087937
# Order: (0, 0, 0), Seasonal Order: (1, 2, 1, 52), RMSE: 11.116889168372005
# Order: (0, 0, 0), Seasonal Order: (1, 2, 2, 52), RMSE: 10.982317736661049
# Order: (0, 0, 0), Seasonal Order: (2, 0, 0, 52), RMSE: 8.564596231691093
# Order: (0, 0, 0), Seasonal Order: (2, 0, 1, 52), RMSE: 8.831074727436357
# Order: (0, 0, 0), Seasonal Order: (2, 0, 2, 52), RMSE: 8.683001089324636
# Order: (0, 0, 0), Seasonal Order: (2, 1, 0, 52), RMSE: 13.214293674899322
# Order: (0, 0, 0), Seasonal Order: (2, 1, 1, 52), RMSE: 13.212691100224957
# Order: (0, 0, 0), Seasonal Order: (2, 1, 2, 52), RMSE: 13.28365119148349
# Order: (0, 0, 0), Seasonal Order: (2, 2, 0, 52), RMSE: 10.982317736670348
# Order: (0, 0, 0), Seasonal Order: (2, 2, 1, 52), RMSE: 10.982317736666698
# Order: (0, 0, 0), Seasonal Order: (2, 2, 2, 52), RMSE: 10.982317736661049
# Order: (0, 0, 1), Seasonal Order: (0, 0, 0, 52), RMSE: 23.953374858855877
# Order: (0, 0, 1), Seasonal Order: (0, 0, 1, 52), RMSE: 23.97694978722088
# Order: (0, 0, 1), Seasonal Order: (0, 0, 2, 52), RMSE: 9.105818615851272
# Order: (0, 0, 1), Seasonal Order: (0, 1, 0, 52), RMSE: 9.646764957458892
# Order: (0, 0, 1), Seasonal Order: (0, 1, 1, 52), RMSE: 10.828808415428586
# Order: (0, 0, 1), Seasonal Order: (0, 1, 2, 52), RMSE: 12.956575870572221
# Order: (0, 0, 1), Seasonal Order: (0, 2, 0, 52), RMSE: 11.548562854411985
# Order: (0, 0, 1), Seasonal Order: (0, 2, 1, 52), RMSE: 13.479705640700532
# Order: (0, 0, 1), Seasonal Order: (0, 2, 2, 52), RMSE: 11.591993282744347
# Order: (0, 0, 1), Seasonal Order: (1, 0, 0, 52), RMSE: 7.889868486541203
# Order: (0, 0, 1), Seasonal Order: (1, 0, 1, 52), RMSE: 9.418037193069223
# Order: (0, 0, 1), Seasonal Order: (1, 0, 2, 52), RMSE: 7.247983651993948
# Order: (0, 0, 1), Seasonal Order: (1, 1, 0, 52), RMSE: 10.899554080976367
# Order: (0, 0, 1), Seasonal Order: (1, 1, 1, 52), RMSE: 11.948094289039398
# Order: (0, 0, 1), Seasonal Order: (1, 1, 2, 52), RMSE: 14.373587894704956
# Order: (0, 0, 1), Seasonal Order: (1, 2, 0, 52), RMSE: 13.10822995671418
# Order: (0, 0, 1), Seasonal Order: (1, 2, 1, 52), RMSE: 13.47858223789285
# Order: (0, 0, 1), Seasonal Order: (1, 2, 2, 52), RMSE: 11.591993282744347
# Order: (0, 0, 1), Seasonal Order: (2, 0, 0, 52), RMSE: 8.532432564117268
# Order: (0, 0, 1), Seasonal Order: (2, 0, 1, 52), RMSE: 8.488344112283697
# Order: (0, 0, 1), Seasonal Order: (2, 0, 2, 52), RMSE: 8.324797442749698
# Order: (0, 0, 1), Seasonal Order: (2, 1, 0, 52), RMSE: 13.630759340130291
# Order: (0, 0, 1), Seasonal Order: (2, 1, 1, 52), RMSE: 13.627291971315326
# Order: (0, 0, 1), Seasonal Order: (2, 1, 2, 52), RMSE: 13.018518548119408
# Order: (0, 0, 1), Seasonal Order: (2, 2, 0, 52), RMSE: 11.591993282744344
# Order: (0, 0, 1), Seasonal Order: (2, 2, 1, 52), RMSE: 11.591993282744344
# Order: (0, 0, 1), Seasonal Order: (2, 2, 2, 52), RMSE: 11.591993282744347
# Order: (0, 0, 2), Seasonal Order: (0, 0, 0, 52), RMSE: 24.023469622312156
# Order: (0, 0, 2), Seasonal Order: (0, 0, 1, 52), RMSE: 23.602182372020494
# Order: (0, 0, 2), Seasonal Order: (0, 0, 2, 52), RMSE: 9.824326222050598
# Order: (0, 0, 2), Seasonal Order: (0, 1, 0, 52), RMSE: 9.648307145879942
# Order: (0, 0, 2), Seasonal Order: (0, 1, 1, 52), RMSE: 10.741900754172187
# Order: (0, 0, 2), Seasonal Order: (0, 1, 2, 52), RMSE: 11.975660876645817
# Order: (0, 0, 2), Seasonal Order: (0, 2, 0, 52), RMSE: 11.778287796434437
# Order: (0, 0, 2), Seasonal Order: (0, 2, 1, 52), RMSE: 13.887817587525708
# Order: (0, 0, 2), Seasonal Order: (0, 2, 2, 52), RMSE: 11.580384110982068
# Order: (0, 0, 2), Seasonal Order: (1, 0, 0, 52), RMSE: 7.68533570794548
# Order: (0, 0, 2), Seasonal Order: (1, 0, 1, 52), RMSE: 8.31187617473533
# Order: (0, 0, 2), Seasonal Order: (1, 0, 2, 52), RMSE: 6.718486614401483
# Order: (0, 0, 2), Seasonal Order: (1, 1, 0, 52), RMSE: 11.378697757853908
# Order: (0, 0, 2), Seasonal Order: (1, 1, 1, 52), RMSE: 13.209667380166733
# Order: (0, 0, 2), Seasonal Order: (1, 1, 2, 52), RMSE: 14.867419622327173
# Order: (0, 0, 2), Seasonal Order: (1, 2, 0, 52), RMSE: 13.75830685097442
# Order: (0, 0, 2), Seasonal Order: (1, 2, 1, 52), RMSE: 13.876375178123062
# Order: (0, 0, 2), Seasonal Order: (1, 2, 2, 52), RMSE: 11.580384110982068
# Order: (0, 0, 2), Seasonal Order: (2, 0, 0, 52), RMSE: 8.582330880283472
# Order: (0, 0, 2), Seasonal Order: (2, 0, 1, 52), RMSE: 8.604556356548416
# Order: (0, 0, 2), Seasonal Order: (2, 0, 2, 52), RMSE: 8.022910179682237
# Order: (0, 0, 2), Seasonal Order: (2, 1, 0, 52), RMSE: 14.649538207864776
# Order: (0, 0, 2), Seasonal Order: (2, 1, 1, 52), RMSE: 14.648609589447945
# Order: (0, 0, 2), Seasonal Order: (2, 1, 2, 52), RMSE: 14.051479773659326
# Order: (0, 0, 2), Seasonal Order: (2, 2, 0, 52), RMSE: 11.580384110981361
# Order: (0, 0, 2), Seasonal Order: (2, 2, 1, 52), RMSE: 11.580384110981361
# Order: (0, 0, 2), Seasonal Order: (2, 2, 2, 52), RMSE: 11.580384110982068
# Order: (0, 0, 3), Seasonal Order: (0, 0, 0, 52), RMSE: 23.832648340004233
# Order: (0, 0, 3), Seasonal Order: (0, 0, 1, 52), RMSE: 23.707366831634683
# Order: (0, 0, 3), Seasonal Order: (0, 0, 2, 52), RMSE: 10.9976019544828
# Order: (0, 0, 3), Seasonal Order: (0, 1, 0, 52), RMSE: 9.715934916388123
# Order: (0, 0, 3), Seasonal Order: (0, 1, 1, 52), RMSE: 10.752120223826214
# Order: (0, 0, 3), Seasonal Order: (0, 1, 2, 52), RMSE: 12.036019971157865
# Order: (0, 0, 3), Seasonal Order: (0, 2, 0, 52), RMSE: 11.867649256374515
# Order: (0, 0, 3), Seasonal Order: (0, 2, 1, 52), RMSE: 14.80663049554462
# Order: (0, 0, 3), Seasonal Order: (0, 2, 2, 52), RMSE: 12.399436945956287
# Order: (0, 0, 3), Seasonal Order: (1, 0, 0, 52), RMSE: 7.802951215357369
# Order: (0, 0, 3), Seasonal Order: (1, 0, 1, 52), RMSE: 9.452094548901048
# Order: (0, 0, 3), Seasonal Order: (1, 0, 2, 52), RMSE: 6.792076544111683
# Order: (0, 0, 3), Seasonal Order: (1, 1, 0, 52), RMSE: 11.376440680685663
# Order: (0, 0, 3), Seasonal Order: (1, 1, 1, 52), RMSE: 13.435870804759386
# Order: (0, 0, 3), Seasonal Order: (1, 1, 2, 52), RMSE: 24.40175090997051
# Order: (0, 0, 3), Seasonal Order: (1, 2, 0, 52), RMSE: 13.57061821843222
# Order: (0, 0, 3), Seasonal Order: (1, 2, 1, 52), RMSE: 13.293601544503854
# Order: (0, 0, 3), Seasonal Order: (1, 2, 2, 52), RMSE: 12.399436945956287
# Order: (0, 0, 3), Seasonal Order: (2, 0, 0, 52), RMSE: 8.60117527135524
# Order: (0, 0, 3), Seasonal Order: (2, 0, 1, 52), RMSE: 8.785656784353822
# Order: (0, 0, 3), Seasonal Order: (2, 0, 2, 52), RMSE: 7.9966329919206895
# Order: (0, 0, 3), Seasonal Order: (2, 1, 0, 52), RMSE: 14.736262212291496
# Order: (0, 0, 3), Seasonal Order: (2, 1, 1, 52), RMSE: 14.736484847407041
# Order: (0, 0, 3), Seasonal Order: (2, 1, 2, 52), RMSE: 19.47794676935181
# Order: (0, 0, 3), Seasonal Order: (2, 2, 0, 52), RMSE: 12.399436945947855
# Order: (0, 0, 3), Seasonal Order: (2, 2, 1, 52), RMSE: 12.399436945947855
# Order: (0, 0, 3), Seasonal Order: (2, 2, 2, 52), RMSE: 12.399436945956287
# Order: (0, 0, 4), Seasonal Order: (0, 0, 0, 52), RMSE: 24.333464353593854
# Order: (0, 0, 4), Seasonal Order: (0, 0, 1, 52), RMSE: 23.54300717171113
# Order: (0, 0, 4), Seasonal Order: (0, 0, 2, 52), RMSE: 10.894705849657363
# Order: (0, 0, 4), Seasonal Order: (0, 1, 0, 52), RMSE: 9.768073026852512
# Order: (0, 0, 4), Seasonal Order: (0, 1, 1, 52), RMSE: 10.73496659994127
# Order: (0, 0, 4), Seasonal Order: (0, 1, 2, 52), RMSE: 12.398732462691857
# Order: (0, 0, 4), Seasonal Order: (0, 2, 0, 52), RMSE: 12.470696709019363
# Order: (0, 0, 4), Seasonal Order: (0, 2, 1, 52), RMSE: 15.421816263798487
# Order: (0, 0, 4), Seasonal Order: (0, 2, 2, 52), RMSE: 12.358771214274707
# Order: (0, 0, 4), Seasonal Order: (1, 0, 0, 52), RMSE: 7.840231421727507
# Order: (0, 0, 4), Seasonal Order: (1, 0, 1, 52), RMSE: 9.090239207825505
# Order: (0, 0, 4), Seasonal Order: (1, 0, 2, 52), RMSE: 6.867015009167941
# Order: (0, 0, 4), Seasonal Order: (1, 1, 0, 52), RMSE: 11.505215839540687
# Order: (0, 0, 4), Seasonal Order: (1, 1, 1, 52), RMSE: 13.27550424968649
# Order: (0, 0, 4), Seasonal Order: (1, 1, 2, 52), RMSE: 18.971435681918393
# Order: (0, 0, 4), Seasonal Order: (1, 2, 0, 52), RMSE: 14.065132843376459
# Order: (0, 0, 4), Seasonal Order: (1, 2, 1, 52), RMSE: 15.343691273434752
# Order: (0, 0, 4), Seasonal Order: (1, 2, 2, 52), RMSE: 12.358771214274707
# Order: (0, 0, 4), Seasonal Order: (2, 0, 0, 52), RMSE: 8.824355854810175
# Order: (0, 0, 4), Seasonal Order: (2, 0, 1, 52), RMSE: 9.122936631136561
# Order: (0, 0, 4), Seasonal Order: (2, 0, 2, 52), RMSE: 9.054814462485794
# Order: (0, 0, 4), Seasonal Order: (2, 1, 0, 52), RMSE: 14.743894916166683
# Order: (0, 0, 4), Seasonal Order: (2, 1, 1, 52), RMSE: 14.7418528875544
# Order: (0, 0, 4), Seasonal Order: (2, 1, 2, 52), RMSE: 21.23989364754204
# Order: (0, 0, 4), Seasonal Order: (2, 2, 0, 52), RMSE: 12.358771214286572
# Order: (0, 0, 4), Seasonal Order: (2, 2, 1, 52), RMSE: 12.358771214286572
# Order: (0, 0, 4), Seasonal Order: (2, 2, 2, 52), RMSE: 12.358771214274707
# Order: (0, 1, 0), Seasonal Order: (0, 0, 0, 52), RMSE: 12.693561010149804
# Order: (0, 1, 0), Seasonal Order: (0, 0, 1, 52), RMSE: 12.693561010149711
# Order: (0, 1, 0), Seasonal Order: (0, 0, 2, 52), RMSE: 14.980721802492507
# Order: (0, 1, 0), Seasonal Order: (0, 1, 0, 52), RMSE: 20.04557674327377
# Order: (0, 1, 0), Seasonal Order: (0, 1, 1, 52), RMSE: 10.748711372450211
# Order: (0, 1, 0), Seasonal Order: (0, 1, 2, 52), RMSE: 16.876132933028938
# Order: (0, 1, 0), Seasonal Order: (0, 2, 0, 52), RMSE: 29.09383491386448
# Order: (0, 1, 0), Seasonal Order: (0, 2, 1, 52), RMSE: 30.354095172577253
# Order: (0, 1, 0), Seasonal Order: (0, 2, 2, 52), RMSE: 29.09383491387067
# Order: (0, 1, 0), Seasonal Order: (1, 0, 0, 52), RMSE: 16.261713318691562
# Order: (0, 1, 0), Seasonal Order: (1, 0, 1, 52), RMSE: 14.185265215890968
# Order: (0, 1, 0), Seasonal Order: (1, 0, 2, 52), RMSE: 14.294325704499748
# Order: (0, 1, 0), Seasonal Order: (1, 1, 0, 52), RMSE: 16.129430794997567
# Order: (0, 1, 0), Seasonal Order: (1, 1, 1, 52), RMSE: 11.543562857845627
# Order: (0, 1, 0), Seasonal Order: (1, 1, 2, 52), RMSE: 12.886521144216937
# Order: (0, 1, 0), Seasonal Order: (1, 2, 0, 52), RMSE: 30.13721780584679
# Order: (0, 1, 0), Seasonal Order: (1, 2, 1, 52), RMSE: 30.358126067854993
# Order: (0, 1, 0), Seasonal Order: (1, 2, 2, 52), RMSE: 29.09383491387067
# Order: (0, 1, 0), Seasonal Order: (2, 0, 0, 52), RMSE: 14.786830085172477
# Order: (0, 1, 0), Seasonal Order: (2, 0, 1, 52), RMSE: 13.922439539748018
# Order: (0, 1, 0), Seasonal Order: (2, 0, 2, 52), RMSE: 10.080102778016222
# Order: (0, 1, 0), Seasonal Order: (2, 1, 0, 52), RMSE: 5.638439736104335
# Order: (0, 1, 0), Seasonal Order: (2, 1, 1, 52), RMSE: 5.638107824491343
# Order: (0, 1, 0), Seasonal Order: (2, 1, 2, 52), RMSE: 5.64501273071029
# Order: (0, 1, 0), Seasonal Order: (2, 2, 0, 52), RMSE: 29.093834913872822
# Order: (0, 1, 0), Seasonal Order: (2, 2, 1, 52), RMSE: 29.093834913875842
# Order: (0, 1, 0), Seasonal Order: (2, 2, 2, 52), RMSE: 29.09383491387067
# Order: (0, 1, 1), Seasonal Order: (0, 0, 0, 52), RMSE: 5.402540003541927
# Order: (0, 1, 1), Seasonal Order: (0, 0, 1, 52), RMSE: 7.0707037521179865
# Order: (0, 1, 1), Seasonal Order: (0, 0, 2, 52), RMSE: 8.03646072649276
# Order: (0, 1, 1), Seasonal Order: (0, 1, 0, 52), RMSE: 9.016746505400057
# Order: (0, 1, 1), Seasonal Order: (0, 1, 1, 52), RMSE: 4.992756952791004
# Order: (0, 1, 1), Seasonal Order: (0, 1, 2, 52), RMSE: 6.889202315006654
# Order: (0, 1, 1), Seasonal Order: (0, 2, 0, 52), RMSE: 16.993678399716043
# Order: (0, 1, 1), Seasonal Order: (0, 2, 1, 52), RMSE: 15.544525597993069
# Order: (0, 1, 1), Seasonal Order: (0, 2, 2, 52), RMSE: 19.02796703660908
# Order: (0, 1, 1), Seasonal Order: (1, 0, 0, 52), RMSE: 7.096291672430586
# Order: (0, 1, 1), Seasonal Order: (1, 0, 1, 52), RMSE: 7.973874538103568
# Order: (0, 1, 1), Seasonal Order: (1, 0, 2, 52), RMSE: 5.366116515678678
# Order: (0, 1, 1), Seasonal Order: (1, 1, 0, 52), RMSE: 6.707609670900651
# Order: (0, 1, 1), Seasonal Order: (1, 1, 1, 52), RMSE: 5.414283530261711
# Order: (0, 1, 1), Seasonal Order: (1, 1, 2, 52), RMSE: 5.2604846165811106
# Order: (0, 1, 1), Seasonal Order: (1, 2, 0, 52), RMSE: 16.30940010241787
# Order: (0, 1, 1), Seasonal Order: (1, 2, 1, 52), RMSE: 14.811233907522926
# Order: (0, 1, 1), Seasonal Order: (1, 2, 2, 52), RMSE: 19.02796703660908
# Order: (0, 1, 1), Seasonal Order: (2, 0, 0, 52), RMSE: 6.28052974099813
# Order: (0, 1, 1), Seasonal Order: (2, 0, 1, 52), RMSE: 7.697339860274195
# Order: (0, 1, 1), Seasonal Order: (2, 0, 2, 52), RMSE: 4.568660018005198
# Order: (0, 1, 1), Seasonal Order: (2, 1, 0, 52), RMSE: 5.41096385674202
# Order: (0, 1, 1), Seasonal Order: (2, 1, 1, 52), RMSE: 5.528900922204633
# Order: (0, 1, 1), Seasonal Order: (2, 1, 2, 52), RMSE: 5.70745029901652
# Order: (0, 1, 1), Seasonal Order: (2, 2, 0, 52), RMSE: 19.027967036605183
# Order: (0, 1, 1), Seasonal Order: (2, 2, 1, 52), RMSE: 19.027967036605183
# Order: (0, 1, 1), Seasonal Order: (2, 2, 2, 52), RMSE: 19.02796703660908
# Order: (0, 1, 2), Seasonal Order: (0, 0, 0, 52), RMSE: 8.22756208151682
# Order: (0, 1, 2), Seasonal Order: (0, 0, 1, 52), RMSE: 6.0927850704634166
# Order: (0, 1, 2), Seasonal Order: (0, 0, 2, 52), RMSE: 6.6963561569036285
# Order: (0, 1, 2), Seasonal Order: (0, 1, 0, 52), RMSE: 8.780428737830158
# Order: (0, 1, 2), Seasonal Order: (0, 1, 1, 52), RMSE: 7.941674075099862
# Order: (0, 1, 2), Seasonal Order: (0, 1, 2, 52), RMSE: 6.786437259811193
# Order: (0, 1, 2), Seasonal Order: (0, 2, 0, 52), RMSE: 16.882786407776408
# Order: (0, 1, 2), Seasonal Order: (0, 2, 1, 52), RMSE: 19.203767712844503
# Order: (0, 1, 2), Seasonal Order: (0, 2, 2, 52), RMSE: 14.323054995645178
# Order: (0, 1, 2), Seasonal Order: (1, 0, 0, 52), RMSE: 6.741194081703732
# Order: (0, 1, 2), Seasonal Order: (1, 0, 1, 52), RMSE: 6.656092147778586
# Order: (0, 1, 2), Seasonal Order: (1, 0, 2, 52), RMSE: 6.096907964634045
# Order: (0, 1, 2), Seasonal Order: (1, 1, 0, 52), RMSE: 6.738675868879159
# Order: (0, 1, 2), Seasonal Order: (1, 1, 1, 52), RMSE: 5.802457463486991
# Order: (0, 1, 2), Seasonal Order: (1, 1, 2, 52), RMSE: 6.790619100493346
# Order: (0, 1, 2), Seasonal Order: (1, 2, 0, 52), RMSE: 16.8412721557017
# Order: (0, 1, 2), Seasonal Order: (1, 2, 1, 52), RMSE: 17.033022361869165
# Order: (0, 1, 2), Seasonal Order: (1, 2, 2, 52), RMSE: 14.323054995645178
# Order: (0, 1, 2), Seasonal Order: (2, 0, 0, 52), RMSE: 6.205026749172603
# Order: (0, 1, 2), Seasonal Order: (2, 0, 1, 52), RMSE: 6.378544233990042
# Order: (0, 1, 2), Seasonal Order: (2, 0, 2, 52), RMSE: 4.833528689946093
# Order: (0, 1, 2), Seasonal Order: (2, 1, 0, 52), RMSE: 6.5494728260780395
# Order: (0, 1, 2), Seasonal Order: (2, 1, 1, 52), RMSE: 5.985727887225331
# Order: (0, 1, 2), Seasonal Order: (2, 1, 2, 52), RMSE: 7.314679476045188
# Order: (0, 1, 2), Seasonal Order: (2, 2, 0, 52), RMSE: 14.32305092014473
# Order: (0, 1, 2), Seasonal Order: (2, 2, 1, 52), RMSE: 14.32305092014473
# Order: (0, 1, 2), Seasonal Order: (2, 2, 2, 52), RMSE: 14.323054995645178
# Order: (0, 1, 3), Seasonal Order: (0, 0, 0, 52), RMSE: 8.391751539375964
# Order: (0, 1, 3), Seasonal Order: (0, 0, 1, 52), RMSE: 5.348201454104579
# Order: (0, 1, 3), Seasonal Order: (0, 0, 2, 52), RMSE: 7.809416710941746
# Order: (0, 1, 3), Seasonal Order: (0, 1, 0, 52), RMSE: 8.720719718879792
# Order: (0, 1, 3), Seasonal Order: (0, 1, 1, 52), RMSE: 8.012144435141524
# Order: (0, 1, 3), Seasonal Order: (0, 1, 2, 52), RMSE: 6.989965904488011
# Order: (0, 1, 3), Seasonal Order: (0, 2, 0, 52), RMSE: 18.321279160428258
# Order: (0, 1, 3), Seasonal Order: (0, 2, 1, 52), RMSE: 18.16425391937711
# Order: (0, 1, 3), Seasonal Order: (0, 2, 2, 52), RMSE: 18.917210985821043
# Order: (0, 1, 3), Seasonal Order: (1, 0, 0, 52), RMSE: 7.146192264012002
# Order: (0, 1, 3), Seasonal Order: (1, 0, 1, 52), RMSE: 5.616477427894216
# Order: (0, 1, 3), Seasonal Order: (1, 0, 2, 52), RMSE: 6.102057555554405
# Order: (0, 1, 3), Seasonal Order: (1, 1, 0, 52), RMSE: 9.422510532576158
# Order: (0, 1, 3), Seasonal Order: (1, 1, 1, 52), RMSE: 9.745414765280245
# Order: (0, 1, 3), Seasonal Order: (1, 1, 2, 52), RMSE: 5.615449418086849
# Order: (0, 1, 3), Seasonal Order: (1, 2, 0, 52), RMSE: 22.85909108057604
# Order: (0, 1, 3), Seasonal Order: (1, 2, 1, 52), RMSE: 17.658025543899218
# Order: (0, 1, 3), Seasonal Order: (1, 2, 2, 52), RMSE: 18.917210985821043
# Order: (0, 1, 3), Seasonal Order: (2, 0, 0, 52), RMSE: 8.366397098663501
# Order: (0, 1, 3), Seasonal Order: (2, 0, 1, 52), RMSE: 5.410431744501885
# Order: (0, 1, 3), Seasonal Order: (2, 0, 2, 52), RMSE: 8.070440403259338
# Order: (0, 1, 3), Seasonal Order: (2, 1, 0, 52), RMSE: 9.480115672240464
# Order: (0, 1, 3), Seasonal Order: (2, 1, 1, 52), RMSE: 5.9794648056717445
# Order: (0, 1, 3), Seasonal Order: (2, 1, 2, 52), RMSE: 9.068317497596015
# Order: (0, 1, 3), Seasonal Order: (2, 2, 0, 52), RMSE: 18.917210985820265
# Order: (0, 1, 3), Seasonal Order: (2, 2, 1, 52), RMSE: 18.917210985820265
# Order: (0, 1, 3), Seasonal Order: (2, 2, 2, 52), RMSE: 18.917210985821043
# Order: (0, 1, 4), Seasonal Order: (0, 0, 0, 52), RMSE: 8.461545794911896
# Order: (0, 1, 4), Seasonal Order: (0, 0, 1, 52), RMSE: 5.257841261594994
# Order: (0, 1, 4), Seasonal Order: (0, 0, 2, 52), RMSE: 7.694406521042676
# Order: (0, 1, 4), Seasonal Order: (0, 1, 0, 52), RMSE: 8.771766512835816
# Order: (0, 1, 4), Seasonal Order: (0, 1, 1, 52), RMSE: 5.104138431905375
# Order: (0, 1, 4), Seasonal Order: (0, 1, 2, 52), RMSE: 10.796041705976636
# Order: (0, 1, 4), Seasonal Order: (0, 2, 0, 52), RMSE: 17.996939638477023
# Order: (0, 1, 4), Seasonal Order: (0, 2, 1, 52), RMSE: 23.373498449670894
# Order: (0, 1, 4), Seasonal Order: (0, 2, 2, 52), RMSE: 18.714758146297132
# Order: (0, 1, 4), Seasonal Order: (1, 0, 0, 52), RMSE: 6.84124435030931
# Order: (0, 1, 4), Seasonal Order: (1, 0, 1, 52), RMSE: 5.471768279177213
# Order: (0, 1, 4), Seasonal Order: (1, 0, 2, 52), RMSE: 7.146463477698787
# Order: (0, 1, 4), Seasonal Order: (1, 1, 0, 52), RMSE: 6.415914546856855
# Order: (0, 1, 4), Seasonal Order: (1, 1, 1, 52), RMSE: 9.88044451814295
# Order: (0, 1, 4), Seasonal Order: (1, 1, 2, 52), RMSE: 5.974521213810544
# Order: (0, 1, 4), Seasonal Order: (1, 2, 0, 52), RMSE: 31.687753347599614
# Order: (0, 1, 4), Seasonal Order: (1, 2, 1, 52), RMSE: 28.294318850255927
# Order: (0, 1, 4), Seasonal Order: (1, 2, 2, 52), RMSE: 18.714758146297132
# Order: (0, 1, 4), Seasonal Order: (2, 0, 0, 52), RMSE: 6.2865598160054885
# Order: (0, 1, 4), Seasonal Order: (2, 0, 1, 52), RMSE: 5.301826245427301
# Order: (0, 1, 4), Seasonal Order: (2, 0, 2, 52), RMSE: 7.962833746344094
# Order: (0, 1, 4), Seasonal Order: (2, 1, 0, 52), RMSE: 6.44931419408129
# Order: (0, 1, 4), Seasonal Order: (2, 1, 1, 52), RMSE: 6.449506240735278
# Order: (0, 1, 4), Seasonal Order: (2, 1, 2, 52), RMSE: 21.881889313665358
# Order: (0, 1, 4), Seasonal Order: (2, 2, 0, 52), RMSE: 18.71475814631636
# Order: (0, 1, 4), Seasonal Order: (2, 2, 1, 52), RMSE: 18.71475814631636
# Order: (0, 1, 4), Seasonal Order: (2, 2, 2, 52), RMSE: 18.714758146297132
# Order: (0, 2, 0), Seasonal Order: (0, 0, 0, 52), RMSE: 167.12133054618005
# Order: (0, 2, 0), Seasonal Order: (0, 0, 1, 52), RMSE: 167.1213305461784
# Order: (0, 2, 0), Seasonal Order: (0, 0, 2, 52), RMSE: 184.5891682310441
# Order: (0, 2, 0), Seasonal Order: (0, 1, 0, 52), RMSE: 211.00345522469863
# Order: (0, 2, 0), Seasonal Order: (0, 1, 1, 52), RMSE: 150.545514925631
# Order: (0, 2, 0), Seasonal Order: (0, 1, 2, 52), RMSE: 205.6896147998366
# Order: (0, 2, 0), Seasonal Order: (0, 2, 0, 52), RMSE: 225.0346497599161
# Order: (0, 2, 0), Seasonal Order: (0, 2, 1, 52), RMSE: 294.7403420390491
# Order: (0, 2, 0), Seasonal Order: (0, 2, 2, 52), RMSE: 225.0346497600776
# Order: (0, 2, 0), Seasonal Order: (1, 0, 0, 52), RMSE: 187.73022551059373
# Order: (0, 2, 0), Seasonal Order: (1, 0, 1, 52), RMSE: 178.09579153893185
# Order: (0, 2, 0), Seasonal Order: (1, 0, 2, 52), RMSE: 185.20996658858385
# Order: (0, 2, 0), Seasonal Order: (1, 1, 0, 52), RMSE: 204.8152405517256
# Order: (0, 2, 0), Seasonal Order: (1, 1, 1, 52), RMSE: 191.94898492014022
# Order: (0, 2, 0), Seasonal Order: (1, 1, 2, 52), RMSE: 188.61727231070782
# Order: (0, 2, 0), Seasonal Order: (1, 2, 0, 52), RMSE: 286.1924030696536
# Order: (0, 2, 0), Seasonal Order: (1, 2, 1, 52), RMSE: 298.31070511576866
# Order: (0, 2, 0), Seasonal Order: (1, 2, 2, 52), RMSE: 225.0346497600776
# Order: (0, 2, 0), Seasonal Order: (2, 0, 0, 52), RMSE: 190.44811182790363
# Order: (0, 2, 0), Seasonal Order: (2, 0, 1, 52), RMSE: 174.65779323783562
# Order: (0, 2, 0), Seasonal Order: (2, 0, 2, 52), RMSE: 182.1803625801298
# Order: (0, 2, 0), Seasonal Order: (2, 1, 0, 52), RMSE: 72.20554901682517
# Order: (0, 2, 0), Seasonal Order: (2, 1, 1, 52), RMSE: 72.19243417320976
# Order: (0, 2, 0), Seasonal Order: (2, 1, 2, 52), RMSE: 92.72949113304479
# Order: (0, 2, 0), Seasonal Order: (2, 2, 0, 52), RMSE: 225.03464975953372
# Order: (0, 2, 0), Seasonal Order: (2, 2, 1, 52), RMSE: 225.03464976029093
# Order: (0, 2, 0), Seasonal Order: (2, 2, 2, 52), RMSE: 225.0346497600776
# Order: (0, 2, 1), Seasonal Order: (0, 0, 0, 52), RMSE: 13.61422066207577
# Order: (0, 2, 1), Seasonal Order: (0, 0, 1, 52), RMSE: 1269.8443838206827
# Order: (0, 2, 1), Seasonal Order: (0, 0, 2, 52), RMSE: 16.115560933918584
# Order: (0, 2, 1), Seasonal Order: (0, 1, 0, 52), RMSE: 20.84732475763476
# Order: (0, 2, 1), Seasonal Order: (0, 1, 1, 52), RMSE: 12.572344794732984
# Order: (0, 2, 1), Seasonal Order: (0, 1, 2, 52), RMSE: 23.97962660122929
# Order: (0, 2, 1), Seasonal Order: (0, 2, 0, 52), RMSE: 34.92601209347377
# Order: (0, 2, 1), Seasonal Order: (0, 2, 1, 52), RMSE: 41.65506520651186
# Order: (0, 2, 1), Seasonal Order: (0, 2, 2, 52), RMSE: 54.34729400621885
# Order: (0, 2, 1), Seasonal Order: (1, 0, 0, 52), RMSE: 16.90760364552422
# Order: (0, 2, 1), Seasonal Order: (1, 0, 1, 52), RMSE: 1669.8292851085926
# Order: (0, 2, 1), Seasonal Order: (1, 0, 2, 52), RMSE: 19.18151194949452
# Order: (0, 2, 1), Seasonal Order: (1, 1, 0, 52), RMSE: 19.050423981227535
# Order: (0, 2, 1), Seasonal Order: (1, 1, 1, 52), RMSE: 17.461869667680247
# Order: (0, 2, 1), Seasonal Order: (1, 1, 2, 52), RMSE: 6.294388924528095
# Order: (0, 2, 1), Seasonal Order: (1, 2, 0, 52), RMSE: 55.51718106864943
# Order: (0, 2, 1), Seasonal Order: (1, 2, 1, 52), RMSE: 55.197769050709994
# Order: (0, 2, 1), Seasonal Order: (1, 2, 2, 52), RMSE: 54.34729400621885
# Order: (0, 2, 1), Seasonal Order: (2, 0, 0, 52), RMSE: 17.378013000741976
# Order: (0, 2, 1), Seasonal Order: (2, 0, 1, 52), RMSE: 570.2863671014647
# Order: (0, 2, 1), Seasonal Order: (2, 0, 2, 52), RMSE: 15.519760203204122
# Order: (0, 2, 1), Seasonal Order: (2, 1, 0, 52), RMSE: 11.973195057892314
# Order: (0, 2, 1), Seasonal Order: (2, 1, 1, 52), RMSE: 18.487832928210725
# Order: (0, 2, 1), Seasonal Order: (2, 1, 2, 52), RMSE: 6.29460120569816
# Order: (0, 2, 1), Seasonal Order: (2, 2, 0, 52), RMSE: 54.34729248582922
# Order: (0, 2, 1), Seasonal Order: (2, 2, 1, 52), RMSE: 54.34729248582922
# Order: (0, 2, 1), Seasonal Order: (2, 2, 2, 52), RMSE: 54.34729400621885
# Order: (0, 2, 2), Seasonal Order: (0, 0, 0, 52), RMSE: 6.015058458270639
# Order: (0, 2, 2), Seasonal Order: (0, 0, 1, 52), RMSE: 573.107988534947
# Order: (0, 2, 2), Seasonal Order: (0, 0, 2, 52), RMSE: 9.752978652639339
# Order: (0, 2, 2), Seasonal Order: (0, 1, 0, 52), RMSE: 9.63896835164965
# Order: (0, 2, 2), Seasonal Order: (0, 1, 1, 52), RMSE: 4.798125478185475
# Order: (0, 2, 2), Seasonal Order: (0, 1, 2, 52), RMSE: 22.712204479241375
# Order: (0, 2, 2), Seasonal Order: (0, 2, 0, 52), RMSE: 31.231405087784598
# Order: (0, 2, 2), Seasonal Order: (0, 2, 1, 52), RMSE: 39.22228568512234
# Order: (0, 2, 2), Seasonal Order: (0, 2, 2, 52), RMSE: 40.303406272980496
# Order: (0, 2, 2), Seasonal Order: (1, 0, 0, 52), RMSE: 7.634389054804909
# Order: (0, 2, 2), Seasonal Order: (1, 0, 1, 52), RMSE: 756.2163701801423
# Order: (0, 2, 2), Seasonal Order: (1, 0, 2, 52), RMSE: 8.334574337595186
# Order: (0, 2, 2), Seasonal Order: (1, 1, 0, 52), RMSE: 8.056445248190768
# Order: (0, 2, 2), Seasonal Order: (1, 1, 1, 52), RMSE: 4.798626885220707
# Order: (0, 2, 2), Seasonal Order: (1, 1, 2, 52), RMSE: 54.827342564454575
# Order: (0, 2, 2), Seasonal Order: (1, 2, 0, 52), RMSE: 48.88872162465168
# Order: (0, 2, 2), Seasonal Order: (1, 2, 1, 52), RMSE: 35.51462517239205
# Order: (0, 2, 2), Seasonal Order: (1, 2, 2, 52), RMSE: 40.303406272980496
# Order: (0, 2, 2), Seasonal Order: (2, 0, 0, 52), RMSE: 7.881293907469976
# Order: (0, 2, 2), Seasonal Order: (2, 0, 1, 52), RMSE: 284.02816420534685
# Order: (0, 2, 2), Seasonal Order: (2, 0, 2, 52), RMSE: 5.554298072489559
# Order: (0, 2, 2), Seasonal Order: (2, 1, 0, 52), RMSE: 11.831940926983727
# Order: (0, 2, 2), Seasonal Order: (2, 1, 1, 52), RMSE: 16.416269133092097
# Order: (0, 2, 2), Seasonal Order: (2, 1, 2, 52), RMSE: 8.551493457741323
# Order: (0, 2, 2), Seasonal Order: (2, 2, 0, 52), RMSE: 40.36130625385222
# Order: (0, 2, 2), Seasonal Order: (2, 2, 1, 52), RMSE: 40.36130625385222
# Order: (0, 2, 2), Seasonal Order: (2, 2, 2, 52), RMSE: 40.303406272980496
# Order: (0, 2, 3), Seasonal Order: (0, 0, 0, 52), RMSE: 6.806650658844927
# Order: (0, 2, 3), Seasonal Order: (0, 0, 1, 52), RMSE: 33083.153348005675
# Order: (0, 2, 3), Seasonal Order: (0, 0, 2, 52), RMSE: 8.23823328074772
# Order: (0, 2, 3), Seasonal Order: (0, 1, 0, 52), RMSE: 9.501206491403607
# Order: (0, 2, 3), Seasonal Order: (0, 1, 1, 52), RMSE: 5.121941928333528
# Order: (0, 2, 3), Seasonal Order: (0, 1, 2, 52), RMSE: 16.41244129539954
# Order: (0, 2, 3), Seasonal Order: (0, 2, 0, 52), RMSE: 32.98762710606594
# Order: (0, 2, 3), Seasonal Order: (0, 2, 1, 52), RMSE: 27.073376774891916
# Order: (0, 2, 3), Seasonal Order: (0, 2, 2, 52), RMSE: 35.32639605661096
# Order: (0, 2, 3), Seasonal Order: (1, 0, 0, 52), RMSE: 7.535292840936142
# Order: (0, 2, 3), Seasonal Order: (1, 0, 1, 52), RMSE: 6732714.117094313
# Order: (0, 2, 3), Seasonal Order: (1, 0, 2, 52), RMSE: 17.349482342917717
# Order: (0, 2, 3), Seasonal Order: (1, 1, 0, 52), RMSE: 22.09942065143358
# Order: (0, 2, 3), Seasonal Order: (1, 1, 1, 52), RMSE: 13.370894628869976
# Order: (0, 2, 3), Seasonal Order: (1, 1, 2, 52), RMSE: 77.09954516038174
# Order: (0, 2, 3), Seasonal Order: (1, 2, 0, 52), RMSE: 61.343055639582694
# Order: (0, 2, 3), Seasonal Order: (1, 2, 1, 52), RMSE: 25.428686608466414
# Order: (0, 2, 3), Seasonal Order: (1, 2, 2, 52), RMSE: 35.32639605661096
# Order: (0, 2, 3), Seasonal Order: (2, 0, 0, 52), RMSE: 7.601149386469852
# Order: (0, 2, 3), Seasonal Order: (2, 0, 1, 52), RMSE: 27562.645018883028
# Order: (0, 2, 3), Seasonal Order: (2, 0, 2, 52), RMSE: 5.648214240607373
# Order: (0, 2, 3), Seasonal Order: (2, 1, 0, 52), RMSE: 13.269264453484185
# Order: (0, 2, 3), Seasonal Order: (2, 1, 1, 52), RMSE: 6.998955933895338
# Order: (0, 2, 3), Seasonal Order: (2, 1, 2, 52), RMSE: 13.878416104716097
# Order: (0, 2, 3), Seasonal Order: (2, 2, 0, 52), RMSE: 35.32637954741153
# Order: (0, 2, 3), Seasonal Order: (2, 2, 1, 52), RMSE: 35.32637954741153
# Order: (0, 2, 3), Seasonal Order: (2, 2, 2, 52), RMSE: 35.32639605661096
# Order: (0, 2, 4), Seasonal Order: (0, 0, 0, 52), RMSE: 6.487403966469104
# Order: (0, 2, 4), Seasonal Order: (0, 0, 1, 52), RMSE: 362038311460.096
# Order: (0, 2, 4), Seasonal Order: (0, 0, 2, 52), RMSE: 15.63145594440463
# Order: (0, 2, 4), Seasonal Order: (0, 1, 0, 52), RMSE: 9.465940154162793
# Order: (0, 2, 4), Seasonal Order: (0, 1, 1, 52), RMSE: 7.383547608624444
# Order: (0, 2, 4), Seasonal Order: (0, 1, 2, 52), RMSE: 31.708430579778597
# Order: (0, 2, 4), Seasonal Order: (0, 2, 0, 52), RMSE: 22.712483130691304
# Order: (0, 2, 4), Seasonal Order: (0, 2, 1, 52), RMSE: 48.967512430689304
# Order: (0, 2, 4), Seasonal Order: (0, 2, 2, 52), RMSE: 29.113254194600383
# Order: (0, 2, 4), Seasonal Order: (1, 0, 0, 52), RMSE: 7.934933732153838
# Order: (0, 2, 4), Seasonal Order: (1, 0, 1, 52), RMSE: 596753647844.4567
# Order: (0, 2, 4), Seasonal Order: (1, 0, 2, 52), RMSE: 8.159787475027825
# Order: (0, 2, 4), Seasonal Order: (1, 1, 0, 52), RMSE: 24.6541123103032
# Order: (0, 2, 4), Seasonal Order: (1, 1, 1, 52), RMSE: 9.519808222798263
# Order: (0, 2, 4), Seasonal Order: (1, 1, 2, 52), RMSE: 35.78758106373162
# Order: (0, 2, 4), Seasonal Order: (1, 2, 0, 52), RMSE: 57.84188696449464
# Order: (0, 2, 4), Seasonal Order: (1, 2, 1, 52), RMSE: 46.06712558866797
# Order: (0, 2, 4), Seasonal Order: (1, 2, 2, 52), RMSE: 29.113254194600383
# Order: (0, 2, 4), Seasonal Order: (2, 0, 0, 52), RMSE: 6.853140010755791
# Order: (0, 2, 4), Seasonal Order: (2, 0, 1, 52), RMSE: 37398199095.79269
# Order: (0, 2, 4), Seasonal Order: (2, 0, 2, 52), RMSE: 7.141138926336004
# Order: (0, 2, 4), Seasonal Order: (2, 1, 0, 52), RMSE: 7.638344743446563
# Order: (0, 2, 4), Seasonal Order: (2, 1, 1, 52), RMSE: 13.857026168419905
# Order: (0, 2, 4), Seasonal Order: (2, 1, 2, 52), RMSE: 20.33885891412786
# Order: (0, 2, 4), Seasonal Order: (2, 2, 0, 52), RMSE: 29.735216447020754
# Order: (0, 2, 4), Seasonal Order: (2, 2, 1, 52), RMSE: 29.735216447020754
# Order: (0, 2, 4), Seasonal Order: (2, 2, 2, 52), RMSE: 29.113254194600383
# Order: (1, 0, 0), Seasonal Order: (0, 0, 0, 52), RMSE: 17.060083463274115
# Order: (1, 0, 0), Seasonal Order: (0, 0, 1, 52), RMSE: 17.06008338418082
# Order: (1, 0, 0), Seasonal Order: (0, 0, 2, 52), RMSE: 14.621063004640982
# Order: (1, 0, 0), Seasonal Order: (0, 1, 0, 52), RMSE: 9.695106409744989
# Order: (1, 0, 0), Seasonal Order: (0, 1, 1, 52), RMSE: 10.69228505944526
# Order: (1, 0, 0), Seasonal Order: (0, 1, 2, 52), RMSE: 10.929897807537234
# Order: (1, 0, 0), Seasonal Order: (0, 2, 0, 52), RMSE: 11.527372191481014
# Order: (1, 0, 0), Seasonal Order: (0, 2, 1, 52), RMSE: 13.707142268692378
# Order: (1, 0, 0), Seasonal Order: (0, 2, 2, 52), RMSE: 11.527372191481703
# Order: (1, 0, 0), Seasonal Order: (1, 0, 0, 52), RMSE: 7.910503219979296
# Order: (1, 0, 0), Seasonal Order: (1, 0, 1, 52), RMSE: 13.291855153327969
# Order: (1, 0, 0), Seasonal Order: (1, 0, 2, 52), RMSE: 6.765644800827872
# Order: (1, 0, 0), Seasonal Order: (1, 1, 0, 52), RMSE: 11.055207043784783
# Order: (1, 0, 0), Seasonal Order: (1, 1, 1, 52), RMSE: 12.011405520351357
# Order: (1, 0, 0), Seasonal Order: (1, 1, 2, 52), RMSE: 15.310881941673939
# Order: (1, 0, 0), Seasonal Order: (1, 2, 0, 52), RMSE: 13.709125021182192
# Order: (1, 0, 0), Seasonal Order: (1, 2, 1, 52), RMSE: 13.6899522454858
# Order: (1, 0, 0), Seasonal Order: (1, 2, 2, 52), RMSE: 11.527372191481703
# Order: (1, 0, 0), Seasonal Order: (2, 0, 0, 52), RMSE: 8.35755607445351
# Order: (1, 0, 0), Seasonal Order: (2, 0, 1, 52), RMSE: 7.874050313768492
# Order: (1, 0, 0), Seasonal Order: (2, 0, 2, 52), RMSE: 7.8907259566868415
# Order: (1, 0, 0), Seasonal Order: (2, 1, 0, 52), RMSE: 11.961454567848559
# Order: (1, 0, 0), Seasonal Order: (2, 1, 1, 52), RMSE: 11.945570347758956
# Order: (1, 0, 0), Seasonal Order: (2, 1, 2, 52), RMSE: 11.942529329461811
# Order: (1, 0, 0), Seasonal Order: (2, 2, 0, 52), RMSE: 11.527372191481703
# Order: (1, 0, 0), Seasonal Order: (2, 2, 1, 52), RMSE: 11.527372191481703
# Order: (1, 0, 0), Seasonal Order: (2, 2, 2, 52), RMSE: 11.527372191481703
# Order: (1, 0, 1), Seasonal Order: (0, 0, 0, 52), RMSE: 6.054787312699466
# Order: (1, 0, 1), Seasonal Order: (0, 0, 1, 52), RMSE: 10.022847306180001
# Order: (1, 0, 1), Seasonal Order: (0, 0, 2, 52), RMSE: 8.503446074968757
# Order: (1, 0, 1), Seasonal Order: (0, 1, 0, 52), RMSE: 8.897393806790035
# Order: (1, 0, 1), Seasonal Order: (0, 1, 1, 52), RMSE: 10.24557797940935
# Order: (1, 0, 1), Seasonal Order: (0, 1, 2, 52), RMSE: 100.29131939535235
# Order: (1, 0, 1), Seasonal Order: (0, 2, 0, 52), RMSE: 12.103496336292453
# Order: (1, 0, 1), Seasonal Order: (0, 2, 1, 52), RMSE: 248.92522651339053
# Order: (1, 0, 1), Seasonal Order: (0, 2, 2, 52), RMSE: 12.190520026688693
# Order: (1, 0, 1), Seasonal Order: (1, 0, 0, 52), RMSE: 7.373749088527839
# Order: (1, 0, 1), Seasonal Order: (1, 0, 1, 52), RMSE: 10.540588936041436
# Order: (1, 0, 1), Seasonal Order: (1, 0, 2, 52), RMSE: 5.795246932381247
# Order: (1, 0, 1), Seasonal Order: (1, 1, 0, 52), RMSE: 10.842891928238245
# Order: (1, 0, 1), Seasonal Order: (1, 1, 1, 52), RMSE: 11.896437158844787
# Order: (1, 0, 1), Seasonal Order: (1, 1, 2, 52), RMSE: 51.25231506440632
# Order: (1, 0, 1), Seasonal Order: (1, 2, 0, 52), RMSE: 101.95194626193891
# Order: (1, 0, 1), Seasonal Order: (1, 2, 1, 52), RMSE: 158.07857027408272
# Order: (1, 0, 1), Seasonal Order: (1, 2, 2, 52), RMSE: 12.190520026688693
# Order: (1, 0, 1), Seasonal Order: (2, 0, 0, 52), RMSE: 8.224657146518982
# Order: (1, 0, 1), Seasonal Order: (2, 0, 1, 52), RMSE: 7.732240146969862
# Order: (1, 0, 1), Seasonal Order: (2, 0, 2, 52), RMSE: 7.7335610711441785
# Order: (1, 0, 1), Seasonal Order: (2, 1, 0, 52), RMSE: 12.048073350347858
# Order: (1, 0, 1), Seasonal Order: (2, 1, 1, 52), RMSE: 38.63374351628128
# Order: (1, 0, 1), Seasonal Order: (2, 1, 2, 52), RMSE: 7.925251126274649
# Order: (1, 0, 1), Seasonal Order: (2, 2, 0, 52), RMSE: 12.190520026672917
# Order: (1, 0, 1), Seasonal Order: (2, 2, 1, 52), RMSE: 12.190520026672917
# Order: (1, 0, 1), Seasonal Order: (2, 2, 2, 52), RMSE: 12.190520026688693
# Order: (1, 0, 2), Seasonal Order: (0, 0, 0, 52), RMSE: 7.125957053571764
# Order: (1, 0, 2), Seasonal Order: (0, 0, 1, 52), RMSE: 7.519721527869742
# Order: (1, 0, 2), Seasonal Order: (0, 0, 2, 52), RMSE: 6.87121702873705
# Order: (1, 0, 2), Seasonal Order: (0, 1, 0, 52), RMSE: 9.096696652738466
# Order: (1, 0, 2), Seasonal Order: (0, 1, 1, 52), RMSE: 9.35827890359106
# Order: (1, 0, 2), Seasonal Order: (0, 1, 2, 52), RMSE: 28.903239793650364
# Order: (1, 0, 2), Seasonal Order: (0, 2, 0, 52), RMSE: 11.894988804157546
# Order: (1, 0, 2), Seasonal Order: (0, 2, 1, 52), RMSE: 115.80827248888033
# Order: (1, 0, 2), Seasonal Order: (0, 2, 2, 52), RMSE: 11.696745320110168
# Order: (1, 0, 2), Seasonal Order: (1, 0, 0, 52), RMSE: 7.086678527011898
# Order: (1, 0, 2), Seasonal Order: (1, 0, 1, 52), RMSE: 8.880650642103513
# Order: (1, 0, 2), Seasonal Order: (1, 0, 2, 52), RMSE: 6.547208091713734
# Order: (1, 0, 2), Seasonal Order: (1, 1, 0, 52), RMSE: 8.755142652012138
# Order: (1, 0, 2), Seasonal Order: (1, 1, 1, 52), RMSE: 9.611538710318685
# Order: (1, 0, 2), Seasonal Order: (1, 1, 2, 52), RMSE: 67.52750374967157
# Order: (1, 0, 2), Seasonal Order: (1, 2, 0, 52), RMSE: 98.7548207514915
# Order: (1, 0, 2), Seasonal Order: (1, 2, 1, 52), RMSE: 207.21745286855676
# Order: (1, 0, 2), Seasonal Order: (1, 2, 2, 52), RMSE: 11.696745320110168
# Order: (1, 0, 2), Seasonal Order: (2, 0, 0, 52), RMSE: 6.261023101106244
# Order: (1, 0, 2), Seasonal Order: (2, 0, 1, 52), RMSE: 8.560508103871763
# Order: (1, 0, 2), Seasonal Order: (2, 0, 2, 52), RMSE: 7.998317824655109
# Order: (1, 0, 2), Seasonal Order: (2, 1, 0, 52), RMSE: 14.77446064137292
# Order: (1, 0, 2), Seasonal Order: (2, 1, 1, 52), RMSE: 22.201332864323778
# Order: (1, 0, 2), Seasonal Order: (2, 1, 2, 52), RMSE: 11.524394359228905
# Order: (1, 0, 2), Seasonal Order: (2, 2, 0, 52), RMSE: 11.696745320110166
# Order: (1, 0, 2), Seasonal Order: (2, 2, 1, 52), RMSE: 11.696745320110166
# Order: (1, 0, 2), Seasonal Order: (2, 2, 2, 52), RMSE: 11.696745320110168
# Order: (1, 0, 3), Seasonal Order: (0, 0, 0, 52), RMSE: 7.023401095115606
# Order: (1, 0, 3), Seasonal Order: (0, 0, 1, 52), RMSE: 5.257633712919479
# Order: (1, 0, 3), Seasonal Order: (0, 0, 2, 52), RMSE: 6.502619227055688
# Order: (1, 0, 3), Seasonal Order: (0, 1, 0, 52), RMSE: 9.355662007656706
# Order: (1, 0, 3), Seasonal Order: (0, 1, 1, 52), RMSE: 7.606163324183942
# Order: (1, 0, 3), Seasonal Order: (0, 1, 2, 52), RMSE: 66.85497935670375
# Order: (1, 0, 3), Seasonal Order: (0, 2, 0, 52), RMSE: 12.489657187539553
# Order: (1, 0, 3), Seasonal Order: (0, 2, 1, 52), RMSE: 68.12127129332747
# Order: (1, 0, 3), Seasonal Order: (0, 2, 2, 52), RMSE: 12.531608933753757
# Order: (1, 0, 3), Seasonal Order: (1, 0, 0, 52), RMSE: 7.5123328198507675
# Order: (1, 0, 3), Seasonal Order: (1, 0, 1, 52), RMSE: 7.513997623174898
# Order: (1, 0, 3), Seasonal Order: (1, 0, 2, 52), RMSE: 6.5536086947260985
# Order: (1, 0, 3), Seasonal Order: (1, 1, 0, 52), RMSE: 11.41283626283062
# Order: (1, 0, 3), Seasonal Order: (1, 1, 1, 52), RMSE: 13.483745786764233
# Order: (1, 0, 3), Seasonal Order: (1, 1, 2, 52), RMSE: 24.86890058109741
# Order: (1, 0, 3), Seasonal Order: (1, 2, 0, 52), RMSE: 305.1325788819103
# Order: (1, 0, 3), Seasonal Order: (1, 2, 1, 52), RMSE: 302.41321124824185
# Order: (1, 0, 3), Seasonal Order: (1, 2, 2, 52), RMSE: 12.531608933753757
# Order: (1, 0, 3), Seasonal Order: (2, 0, 0, 52), RMSE: 8.7501095268251
# Order: (1, 0, 3), Seasonal Order: (2, 0, 1, 52), RMSE: 8.904961374781092
# Order: (1, 0, 3), Seasonal Order: (2, 0, 2, 52), RMSE: 9.364569543176076
# Order: (1, 0, 3), Seasonal Order: (2, 1, 0, 52), RMSE: 12.650376455858673
# Order: (1, 0, 3), Seasonal Order: (2, 1, 1, 52), RMSE: 10.476208290501706
# Order: (1, 0, 3), Seasonal Order: (2, 1, 2, 52), RMSE: 20.090642643062953
# Order: (1, 0, 3), Seasonal Order: (2, 2, 0, 52), RMSE: 12.531608933753763
# Order: (1, 0, 3), Seasonal Order: (2, 2, 1, 52), RMSE: 12.531608933753763
# Order: (1, 0, 3), Seasonal Order: (2, 2, 2, 52), RMSE: 12.531608933753757
# Order: (1, 0, 4), Seasonal Order: (0, 0, 0, 52), RMSE: 7.032835257411605
# Order: (1, 0, 4), Seasonal Order: (0, 0, 1, 52), RMSE: 5.985299598184906
# Order: (1, 0, 4), Seasonal Order: (0, 0, 2, 52), RMSE: 6.334850107726941
# Order: (1, 0, 4), Seasonal Order: (0, 1, 0, 52), RMSE: 9.184930241606196
# Order: (1, 0, 4), Seasonal Order: (0, 1, 1, 52), RMSE: 8.142726378992725
# Order: (1, 0, 4), Seasonal Order: (0, 1, 2, 52), RMSE: 1108.7993505676684
# Order: (1, 0, 4), Seasonal Order: (0, 2, 0, 52), RMSE: 12.657622142362728
# Order: (1, 0, 4), Seasonal Order: (0, 2, 1, 52), RMSE: 104.52117364954599
# Order: (1, 0, 4), Seasonal Order: (0, 2, 2, 52), RMSE: 12.735253976764518
# Order: (1, 0, 4), Seasonal Order: (1, 0, 0, 52), RMSE: 7.330677405611136
# Order: (1, 0, 4), Seasonal Order: (1, 0, 1, 52), RMSE: 7.347458492847201
# Order: (1, 0, 4), Seasonal Order: (1, 0, 2, 52), RMSE: 6.863483241480721
# Order: (1, 0, 4), Seasonal Order: (1, 1, 0, 52), RMSE: 8.804216857524956
# Order: (1, 0, 4), Seasonal Order: (1, 1, 1, 52), RMSE: 11.096261673341877
# Order: (1, 0, 4), Seasonal Order: (1, 1, 2, 52), RMSE: 5510.212745715509
# Order: (1, 0, 4), Seasonal Order: (1, 2, 0, 52), RMSE: 236.8169062104173
# Order: (1, 0, 4), Seasonal Order: (1, 2, 1, 52), RMSE: 172.93031245400184
# Order: (1, 0, 4), Seasonal Order: (1, 2, 2, 52), RMSE: 12.735253976764518
# Order: (1, 0, 4), Seasonal Order: (2, 0, 0, 52), RMSE: 6.038566945327222
# Order: (1, 0, 4), Seasonal Order: (2, 0, 1, 52), RMSE: 10.90787192271833
# Order: (1, 0, 4), Seasonal Order: (2, 0, 2, 52), RMSE: 9.470879021506871
# Order: (1, 0, 4), Seasonal Order: (2, 1, 0, 52), RMSE: 15.310239641142642
# Order: (1, 0, 4), Seasonal Order: (2, 1, 1, 52), RMSE: 13.782377710105074
# Order: (1, 0, 4), Seasonal Order: (2, 1, 2, 52), RMSE: 19.569745744565143
# Order: (1, 0, 4), Seasonal Order: (2, 2, 0, 52), RMSE: 12.735253976674922
# Order: (1, 0, 4), Seasonal Order: (2, 2, 1, 52), RMSE: 12.735253976674922
# Order: (1, 0, 4), Seasonal Order: (2, 2, 2, 52), RMSE: 12.735253976764518
# Order: (1, 1, 0), Seasonal Order: (0, 0, 0, 52), RMSE: 8.97791597661348
# Order: (1, 1, 0), Seasonal Order: (0, 0, 1, 52), RMSE: 8.97791597661341
# Order: (1, 1, 0), Seasonal Order: (0, 0, 2, 52), RMSE: 12.456095570904269
# Order: (1, 1, 0), Seasonal Order: (0, 1, 0, 52), RMSE: 13.971567737151704
# Order: (1, 1, 0), Seasonal Order: (0, 1, 1, 52), RMSE: 7.5221382840676
# Order: (1, 1, 0), Seasonal Order: (0, 1, 2, 52), RMSE: 8.834283576558871
# Order: (1, 1, 0), Seasonal Order: (0, 2, 0, 52), RMSE: 22.85991702862508
# Order: (1, 1, 0), Seasonal Order: (0, 2, 1, 52), RMSE: 24.909442770756055
# Order: (1, 1, 0), Seasonal Order: (0, 2, 2, 52), RMSE: 22.859917028626725
# Order: (1, 1, 0), Seasonal Order: (1, 0, 0, 52), RMSE: 11.85534681501946
# Order: (1, 1, 0), Seasonal Order: (1, 0, 1, 52), RMSE: 10.108415638357311
# Order: (1, 1, 0), Seasonal Order: (1, 0, 2, 52), RMSE: 9.741205887955326
# Order: (1, 1, 0), Seasonal Order: (1, 1, 0, 52), RMSE: 10.76100539694145
# Order: (1, 1, 0), Seasonal Order: (1, 1, 1, 52), RMSE: 6.467280218664834
# Order: (1, 1, 0), Seasonal Order: (1, 1, 2, 52), RMSE: 5.892073364098784
# Order: (1, 1, 0), Seasonal Order: (1, 2, 0, 52), RMSE: 24.15700884383739
# Order: (1, 1, 0), Seasonal Order: (1, 2, 1, 52), RMSE: 24.16136749157245
# Order: (1, 1, 0), Seasonal Order: (1, 2, 2, 52), RMSE: 22.859917028626725
# Order: (1, 1, 0), Seasonal Order: (2, 0, 0, 52), RMSE: 10.62475344653854
# Order: (1, 1, 0), Seasonal Order: (2, 0, 1, 52), RMSE: 9.813271209509573
# Order: (1, 1, 0), Seasonal Order: (2, 0, 2, 52), RMSE: 5.835365128900383
# Order: (1, 1, 0), Seasonal Order: (2, 1, 0, 52), RMSE: 5.090760801046556
# Order: (1, 1, 0), Seasonal Order: (2, 1, 1, 52), RMSE: 6.212331567012134
# Order: (1, 1, 0), Seasonal Order: (2, 1, 2, 52), RMSE: 5.973348797251673
# Order: (1, 1, 0), Seasonal Order: (2, 2, 0, 52), RMSE: 22.859917028626725
# Order: (1, 1, 0), Seasonal Order: (2, 2, 1, 52), RMSE: 22.859917028626725
# Order: (1, 1, 0), Seasonal Order: (2, 2, 2, 52), RMSE: 22.859917028626725
# Order: (1, 1, 1), Seasonal Order: (0, 0, 0, 52), RMSE: 8.37266636794746
# Order: (1, 1, 1), Seasonal Order: (0, 0, 1, 52), RMSE: 6.004425355281234
# Order: (1, 1, 1), Seasonal Order: (0, 0, 2, 52), RMSE: 7.517961516328702
# Order: (1, 1, 1), Seasonal Order: (0, 1, 0, 52), RMSE: 8.768117078615854
# Order: (1, 1, 1), Seasonal Order: (0, 1, 1, 52), RMSE: 8.040238720283456
# Order: (1, 1, 1), Seasonal Order: (0, 1, 2, 52), RMSE: 6.340688762458241
# Order: (1, 1, 1), Seasonal Order: (0, 2, 0, 52), RMSE: 17.016405231313286
# Order: (1, 1, 1), Seasonal Order: (0, 2, 1, 52), RMSE: 15.203594961178203
# Order: (1, 1, 1), Seasonal Order: (0, 2, 2, 52), RMSE: 17.802723236398812
# Order: (1, 1, 1), Seasonal Order: (1, 0, 0, 52), RMSE: 6.605436705882522
# Order: (1, 1, 1), Seasonal Order: (1, 0, 1, 52), RMSE: 6.548990468991487
# Order: (1, 1, 1), Seasonal Order: (1, 0, 2, 52), RMSE: 5.48496742141905
# Order: (1, 1, 1), Seasonal Order: (1, 1, 0, 52), RMSE: 6.671962699003864
# Order: (1, 1, 1), Seasonal Order: (1, 1, 1, 52), RMSE: 9.237478180380258
# Order: (1, 1, 1), Seasonal Order: (1, 1, 2, 52), RMSE: 5.320748634481255
# Order: (1, 1, 1), Seasonal Order: (1, 2, 0, 52), RMSE: 17.658371093822986
# Order: (1, 1, 1), Seasonal Order: (1, 2, 1, 52), RMSE: 13.515121113892842
# Order: (1, 1, 1), Seasonal Order: (1, 2, 2, 52), RMSE: 17.802723236398812
# Order: (1, 1, 1), Seasonal Order: (2, 0, 0, 52), RMSE: 6.000365000424393
# Order: (1, 1, 1), Seasonal Order: (2, 0, 1, 52), RMSE: 6.303867193052919
# Order: (1, 1, 1), Seasonal Order: (2, 0, 2, 52), RMSE: 7.8598439075688376
# Order: (1, 1, 1), Seasonal Order: (2, 1, 0, 52), RMSE: 6.708632061615391
# Order: (1, 1, 1), Seasonal Order: (2, 1, 1, 52), RMSE: 6.70530462972332
# Order: (1, 1, 1), Seasonal Order: (2, 1, 2, 52), RMSE: 6.169428979423906
# Order: (1, 1, 1), Seasonal Order: (2, 2, 0, 52), RMSE: 17.80272323162559
# Order: (1, 1, 1), Seasonal Order: (2, 2, 1, 52), RMSE: 17.80272323162559
# Order: (1, 1, 1), Seasonal Order: (2, 2, 2, 52), RMSE: 17.802723236398812
# Order: (1, 1, 2), Seasonal Order: (0, 0, 0, 52), RMSE: 8.374812779540354
# Order: (1, 1, 2), Seasonal Order: (0, 0, 1, 52), RMSE: 6.308951072258259
# Order: (1, 1, 2), Seasonal Order: (0, 0, 2, 52), RMSE: 7.78197420978424
# Order: (1, 1, 2), Seasonal Order: (0, 1, 0, 52), RMSE: 8.280261634574936
# Order: (1, 1, 2), Seasonal Order: (0, 1, 1, 52), RMSE: 7.804621839892839
# Order: (1, 1, 2), Seasonal Order: (0, 1, 2, 52), RMSE: 6.284622020762725
# Order: (1, 1, 2), Seasonal Order: (0, 2, 0, 52), RMSE: 17.153477387478414
# Order: (1, 1, 2), Seasonal Order: (0, 2, 1, 52), RMSE: 19.17451141997908
# Order: (1, 1, 2), Seasonal Order: (0, 2, 2, 52), RMSE: 16.424936857682557
# Order: (1, 1, 2), Seasonal Order: (1, 0, 0, 52), RMSE: 7.100461161543568
# Order: (1, 1, 2), Seasonal Order: (1, 0, 1, 52), RMSE: 6.95204919999659
# Order: (1, 1, 2), Seasonal Order: (1, 0, 2, 52), RMSE: 6.096987641760518
# Order: (1, 1, 2), Seasonal Order: (1, 1, 0, 52), RMSE: 8.61319843948675
# Order: (1, 1, 2), Seasonal Order: (1, 1, 1, 52), RMSE: 9.126111748235695
# Order: (1, 1, 2), Seasonal Order: (1, 1, 2, 52), RMSE: 6.240241682581238
# Order: (1, 1, 2), Seasonal Order: (1, 2, 0, 52), RMSE: 18.600107923551946
# Order: (1, 1, 2), Seasonal Order: (1, 2, 1, 52), RMSE: 18.184982417339445
# Order: (1, 1, 2), Seasonal Order: (1, 2, 2, 52), RMSE: 16.424936857682557
# Order: (1, 1, 2), Seasonal Order: (2, 0, 0, 52), RMSE: 6.094822639160518
# Order: (1, 1, 2), Seasonal Order: (2, 0, 1, 52), RMSE: 6.661265488122462
# Order: (1, 1, 2), Seasonal Order: (2, 0, 2, 52), RMSE: 7.722164806906589
# Order: (1, 1, 2), Seasonal Order: (2, 1, 0, 52), RMSE: 6.7104454505014095
# Order: (1, 1, 2), Seasonal Order: (2, 1, 1, 52), RMSE: 6.157900451230243
# Order: (1, 1, 2), Seasonal Order: (2, 1, 2, 52), RMSE: 5.032313927576353
# Order: (1, 1, 2), Seasonal Order: (2, 2, 0, 52), RMSE: 16.424942005122478
# Order: (1, 1, 2), Seasonal Order: (2, 2, 1, 52), RMSE: 16.424942005122478
# Order: (1, 1, 2), Seasonal Order: (2, 2, 2, 52), RMSE: 16.424936857682557
# Order: (1, 1, 3), Seasonal Order: (0, 0, 0, 52), RMSE: 8.498571499547872
# Order: (1, 1, 3), Seasonal Order: (0, 0, 1, 52), RMSE: 5.34743980647649
# Order: (1, 1, 3), Seasonal Order: (0, 0, 2, 52), RMSE: 7.807232046870986
# Order: (1, 1, 3), Seasonal Order: (0, 1, 0, 52), RMSE: 8.726654951911748
# Order: (1, 1, 3), Seasonal Order: (0, 1, 1, 52), RMSE: 7.984568351289714
# Order: (1, 1, 3), Seasonal Order: (0, 1, 2, 52), RMSE: 7388.078710083531
# Order: (1, 1, 3), Seasonal Order: (0, 2, 0, 52), RMSE: 18.219992297086172
# Order: (1, 1, 3), Seasonal Order: (0, 2, 1, 52), RMSE: 30.401351604066807
# Order: (1, 1, 3), Seasonal Order: (0, 2, 2, 52), RMSE: 18.06246874316611
# Order: (1, 1, 3), Seasonal Order: (1, 0, 0, 52), RMSE: 7.192306655001372
# Order: (1, 1, 3), Seasonal Order: (1, 0, 1, 52), RMSE: 5.615243801909344
# Order: (1, 1, 3), Seasonal Order: (1, 0, 2, 52), RMSE: 7.644626808681953
# Order: (1, 1, 3), Seasonal Order: (1, 1, 0, 52), RMSE: 9.480534260930533
# Order: (1, 1, 3), Seasonal Order: (1, 1, 1, 52), RMSE: 9.80581750533517
# Order: (1, 1, 3), Seasonal Order: (1, 1, 2, 52), RMSE: 40.99351234528377
# Order: (1, 1, 3), Seasonal Order: (1, 2, 0, 52), RMSE: 28.12922192885511
# Order: (1, 1, 3), Seasonal Order: (1, 2, 1, 52), RMSE: 325.6554684602759
# Order: (1, 1, 3), Seasonal Order: (1, 2, 2, 52), RMSE: 18.06246874316611
# Order: (1, 1, 3), Seasonal Order: (2, 0, 0, 52), RMSE: 8.569471738638448
# Order: (1, 1, 3), Seasonal Order: (2, 0, 1, 52), RMSE: 5.40948592323244
# Order: (1, 1, 3), Seasonal Order: (2, 0, 2, 52), RMSE: 8.079094626083908
# Order: (1, 1, 3), Seasonal Order: (2, 1, 0, 52), RMSE: 7.674493969811605
# Order: (1, 1, 3), Seasonal Order: (2, 1, 1, 52), RMSE: 7.674675675304567
# Order: (1, 1, 3), Seasonal Order: (2, 1, 2, 52), RMSE: 5.9065717398902535
# Order: (1, 1, 3), Seasonal Order: (2, 2, 0, 52), RMSE: 18.062468734033583
# Order: (1, 1, 3), Seasonal Order: (2, 2, 1, 52), RMSE: 18.062468734033583
# Order: (1, 1, 3), Seasonal Order: (2, 2, 2, 52), RMSE: 18.06246874316611
# Order: (1, 1, 4), Seasonal Order: (0, 0, 0, 52), RMSE: 8.403229822230596
# Order: (1, 1, 4), Seasonal Order: (0, 0, 1, 52), RMSE: 5.463446970779609
# Order: (1, 1, 4), Seasonal Order: (0, 0, 2, 52), RMSE: 7.662584803349314
# Order: (1, 1, 4), Seasonal Order: (0, 1, 0, 52), RMSE: 9.012735437330926
# Order: (1, 1, 4), Seasonal Order: (0, 1, 1, 52), RMSE: 8.062726803973893
# Order: (1, 1, 4), Seasonal Order: (0, 1, 2, 52), RMSE: 59667680.213538505
# ...
# Order: (3, 1, 1), Seasonal Order: (2, 2, 2, 52), RMSE: 19.963694019830452
# Order: (3, 1, 2), Seasonal Order: (0, 0, 0, 52), RMSE: 8.406641823505622
# Order: (3, 1, 2), Seasonal Order: (0, 0, 1, 52), RMSE: 1.285192791759069e+50
# Order: (3, 1, 2), Seasonal Order: (0, 0, 2, 52), RMSE: 7.6499308637860075
# Order: (3, 1, 2), Seasonal Order: (0, 1, 0, 52), RMSE: 8.731560163409767
# Order: (3, 1, 2), Seasonal Order: (0, 1, 1, 52), RMSE: 5.992515356115158
# Order: (3, 1, 2), Seasonal Order: (0, 1, 2, 52), RMSE: 2705.128667098122
# Order: (3, 1, 2), Seasonal Order: (0, 2, 0, 52), RMSE: 16.345893747825617
# Order: (3, 1, 2), Seasonal Order: (0, 2, 1, 52), RMSE: 8921.09309810963
# Order: (3, 1, 2), Seasonal Order: (0, 2, 2, 52), RMSE: 281728.37694995175
# Order: (3, 1, 2), Seasonal Order: (1, 0, 0, 52), RMSE: 7.227234437928685
# Order: (3, 1, 2), Seasonal Order: (1, 0, 1, 52), RMSE: 6.256177970991292e+49
# Order: (3, 1, 2), Seasonal Order: (1, 0, 2, 52), RMSE: 7.503575624354066
# Order: (3, 1, 2), Seasonal Order: (1, 1, 0, 52), RMSE: 7.724289967182046
# Order: (3, 1, 2), Seasonal Order: (1, 1, 1, 52), RMSE: 11.076951802423022
# Order: (3, 1, 2), Seasonal Order: (1, 1, 2, 52), RMSE: 13.9981990012848
# Order: (3, 1, 2), Seasonal Order: (1, 2, 0, 52), RMSE: 23.44888772209287
# Order: (3, 1, 2), Seasonal Order: (1, 2, 1, 52), RMSE: 777.8823338497288
# Order: (3, 1, 2), Seasonal Order: (1, 2, 2, 52), RMSE: 281728.37694995175
# Order: (3, 1, 2), Seasonal Order: (2, 0, 0, 52), RMSE: 6.661891260282939
# Order: (3, 1, 2), Seasonal Order: (2, 0, 1, 52), RMSE: 1.0286213946886565e+49
# Order: (3, 1, 2), Seasonal Order: (2, 0, 2, 52), RMSE: 4.97082664378145
# Order: (3, 1, 2), Seasonal Order: (2, 1, 0, 52), RMSE: 261.4774530661012
# Order: (3, 1, 2), Seasonal Order: (2, 1, 1, 52), RMSE: 494972.6310801432
# Order: (3, 1, 2), Seasonal Order: (2, 1, 2, 52), RMSE: 5346.756839965394
# Order: (3, 1, 2), Seasonal Order: (2, 2, 0, 52), RMSE: 281728.37694995175
# Order: (3, 1, 2), Seasonal Order: (2, 2, 1, 52), RMSE: 281728.37694995175
# Order: (3, 1, 2), Seasonal Order: (2, 2, 2, 52), RMSE: 281728.37694995175
# Order: (3, 1, 3), Seasonal Order: (0, 0, 0, 52), RMSE: 8.262651689571832
# Order: (3, 1, 3), Seasonal Order: (0, 0, 1, 52), RMSE: 5.267187822622469
# Order: (3, 1, 3), Seasonal Order: (0, 0, 2, 52), RMSE: 7.086429674441124
# Order: (3, 1, 3), Seasonal Order: (0, 1, 0, 52), RMSE: 9.024391835966387
# Order: (3, 1, 3), Seasonal Order: (0, 1, 1, 52), RMSE: 6.4694085294265244
# Order: (3, 1, 3), Seasonal Order: (0, 1, 2, 52), RMSE: 2098251.3349901
# Order: (3, 1, 3), Seasonal Order: (0, 2, 0, 52), RMSE: 17.771177056613116
# Order: (3, 1, 3), Seasonal Order: (0, 2, 1, 52), RMSE: 20.112159389866267
# Order: (3, 1, 3), Seasonal Order: (0, 2, 2, 52), RMSE: 17.728271930360915
# Order: (3, 1, 3), Seasonal Order: (1, 0, 0, 52), RMSE: 7.650205192868666
# Order: (3, 1, 3), Seasonal Order: (1, 0, 1, 52), RMSE: 5.459424526265326
# Order: (3, 1, 3), Seasonal Order: (1, 0, 2, 52), RMSE: 8.365371744948478
# Order: (3, 1, 3), Seasonal Order: (1, 1, 0, 52), RMSE: 7.016838260518816
# Order: (3, 1, 3), Seasonal Order: (1, 1, 1, 52), RMSE: 9.408587831772946
# Order: (3, 1, 3), Seasonal Order: (1, 1, 2, 52), RMSE: 734833.790817238
# Order: (3, 1, 3), Seasonal Order: (1, 2, 0, 52), RMSE: 20.260282174320555
# Order: (3, 1, 3), Seasonal Order: (1, 2, 1, 52), RMSE: 19.95149333973582
# Order: (3, 1, 3), Seasonal Order: (1, 2, 2, 52), RMSE: 17.728271930360915
# Order: (3, 1, 3), Seasonal Order: (2, 0, 0, 52), RMSE: 5.869524335970301
# Order: (3, 1, 3), Seasonal Order: (2, 0, 1, 52), RMSE: 5.2945044352474095
# Order: (3, 1, 3), Seasonal Order: (2, 0, 2, 52), RMSE: 8.150707984397707
# Order: (3, 1, 3), Seasonal Order: (2, 1, 0, 52), RMSE: 13.612337921802736
# Order: (3, 1, 3), Seasonal Order: (2, 1, 1, 52), RMSE: 210.63368360746395
# Order: (3, 1, 3), Seasonal Order: (2, 1, 2, 52), RMSE: 302964.79513124586
# Order: (3, 1, 3), Seasonal Order: (2, 2, 0, 52), RMSE: 17.72827192923704
# Order: (3, 1, 3), Seasonal Order: (2, 2, 1, 52), RMSE: 17.72827192923704
# Order: (3, 1, 3), Seasonal Order: (2, 2, 2, 52), RMSE: 17.728271930360915
# Order: (3, 1, 4), Seasonal Order: (0, 0, 0, 52), RMSE: 8.489562214124563
# Order: (3, 1, 4), Seasonal Order: (0, 0, 1, 52), RMSE: 5.16098420615355
# Order: (3, 1, 4), Seasonal Order: (0, 0, 2, 52), RMSE: 7.636064795289831
# Order: (3, 1, 4), Seasonal Order: (0, 1, 0, 52), RMSE: 8.699289866532862
# Order: (3, 1, 4), Seasonal Order: (0, 1, 1, 52), RMSE: 8.104830744088295
# Order: (3, 1, 4), Seasonal Order: (0, 1, 2, 52), RMSE: 2067754.6192933512
# Order: (3, 1, 4), Seasonal Order: (0, 2, 0, 52), RMSE: 17.81288271697875
# Order: (3, 1, 4), Seasonal Order: (0, 2, 1, 52), RMSE: 8877646.507313387
# Order: (3, 1, 4), Seasonal Order: (0, 2, 2, 52), RMSE: 17.887135169735544
# Order: (3, 1, 4), Seasonal Order: (1, 0, 0, 52), RMSE: 7.097903599795289
# Order: (3, 1, 4), Seasonal Order: (1, 0, 1, 52), RMSE: 5.458664258421489
# Order: (3, 1, 4), Seasonal Order: (1, 0, 2, 52), RMSE: 8.751213793871479
# Order: (3, 1, 4), Seasonal Order: (1, 1, 0, 52), RMSE: 6.457385206816741
# Order: (3, 1, 4), Seasonal Order: (1, 1, 1, 52), RMSE: 9.552712106124083
# Order: (3, 1, 4), Seasonal Order: (1, 1, 2, 52), RMSE: 5727528.788320616
# Order: (3, 1, 4), Seasonal Order: (1, 2, 0, 52), RMSE: 19.255485735071073
# Order: (3, 1, 4), Seasonal Order: (1, 2, 1, 52), RMSE: 19.927742891865364
# Order: (3, 1, 4), Seasonal Order: (1, 2, 2, 52), RMSE: 17.887135169735544
# Order: (3, 1, 4), Seasonal Order: (2, 0, 0, 52), RMSE: 6.089355013622365
# Order: (3, 1, 4), Seasonal Order: (2, 0, 1, 52), RMSE: 5.275452058792803
# Order: (3, 1, 4), Seasonal Order: (2, 0, 2, 52), RMSE: 6.359400798889456
# Order: (3, 1, 4), Seasonal Order: (2, 1, 0, 52), RMSE: 14.433019127150787
# Order: (3, 1, 4), Seasonal Order: (2, 1, 1, 52), RMSE: 2772175.2339558084
# Order: (3, 1, 4), Seasonal Order: (2, 1, 2, 52), RMSE: 38052419.903382786
# Order: (3, 1, 4), Seasonal Order: (2, 2, 0, 52), RMSE: 17.88713516394087
# Order: (3, 1, 4), Seasonal Order: (2, 2, 1, 52), RMSE: 17.88713516394087
# Order: (3, 1, 4), Seasonal Order: (2, 2, 2, 52), RMSE: 17.887135169735544
# Order: (3, 2, 0), Seasonal Order: (0, 0, 0, 52), RMSE: 45.979241118464095
# Order: (3, 2, 0), Seasonal Order: (0, 0, 1, 52), RMSE: 45.97955731508688
# Order: (3, 2, 0), Seasonal Order: (0, 0, 2, 52), RMSE: 59.07607032005366
# Order: (3, 2, 0), Seasonal Order: (0, 1, 0, 52), RMSE: 52.26953758520465
# Order: (3, 2, 0), Seasonal Order: (0, 1, 1, 52), RMSE: 47.84327865597219
# Order: (3, 2, 0), Seasonal Order: (0, 1, 2, 52), RMSE: 54.306353359528785
# Order: (3, 2, 0), Seasonal Order: (0, 2, 0, 52), RMSE: 47.03692466124867
# Order: (3, 2, 0), Seasonal Order: (0, 2, 1, 52), RMSE: 81.56729019673354
# Order: (3, 2, 0), Seasonal Order: (0, 2, 2, 52), RMSE: 47.036924661162665
# Order: (3, 2, 0), Seasonal Order: (1, 0, 0, 52), RMSE: 54.420119514658126
# Order: (3, 2, 0), Seasonal Order: (1, 0, 1, 52), RMSE: 48.855053954427454
# Order: (3, 2, 0), Seasonal Order: (1, 0, 2, 52), RMSE: 57.734784794309014
# Order: (3, 2, 0), Seasonal Order: (1, 1, 0, 52), RMSE: 62.138631798709476
# Order: (3, 2, 0), Seasonal Order: (1, 1, 1, 52), RMSE: 53.16533518661909
# Order: (3, 2, 0), Seasonal Order: (1, 1, 2, 52), RMSE: 49.206777669205316
# Order: (3, 2, 0), Seasonal Order: (1, 2, 0, 52), RMSE: 57.08859690321919
# Order: (3, 2, 0), Seasonal Order: (1, 2, 1, 52), RMSE: 57.10664787658826
# Order: (3, 2, 0), Seasonal Order: (1, 2, 2, 52), RMSE: 47.036924661162665
# Order: (3, 2, 0), Seasonal Order: (2, 0, 0, 52), RMSE: 62.810319322260035
# Order: (3, 2, 0), Seasonal Order: (2, 0, 1, 52), RMSE: 46.7578385429369
# Order: (3, 2, 0), Seasonal Order: (2, 0, 2, 52), RMSE: 55.40147732749293
# Order: (3, 2, 0), Seasonal Order: (2, 1, 0, 52), RMSE: 1900144.440586429
# Order: (3, 2, 0), Seasonal Order: (2, 1, 1, 52), RMSE: 1901518.8122903574
# Order: (3, 2, 0), Seasonal Order: (2, 1, 2, 52), RMSE: 1900351.503777667
# Order: (3, 2, 0), Seasonal Order: (2, 2, 0, 52), RMSE: 47.03692466116254
# Order: (3, 2, 0), Seasonal Order: (2, 2, 1, 52), RMSE: 47.03692466116254
# Order: (3, 2, 0), Seasonal Order: (2, 2, 2, 52), RMSE: 47.03692466116254
# Order: (3, 2, 1), Seasonal Order: (0, 0, 0, 52), RMSE: 7.459114874758531
# Order: (3, 2, 1), Seasonal Order: (0, 0, 1, 52), RMSE: 28.93549684432146
# Order: (3, 2, 1), Seasonal Order: (0, 0, 2, 52), RMSE: 9.966316651759405
# Order: (3, 2, 1), Seasonal Order: (0, 1, 0, 52), RMSE: 12.392492730596821
# Order: (3, 2, 1), Seasonal Order: (0, 1, 1, 52), RMSE: 5.8404385674131625
# Order: (3, 2, 1), Seasonal Order: (0, 1, 2, 52), RMSE: 783100.0271086082
# Order: (3, 2, 1), Seasonal Order: (0, 2, 0, 52), RMSE: 24.564968473989598
# Order: (3, 2, 1), Seasonal Order: (0, 2, 1, 52), RMSE: 20492.577282368286
# Order: (3, 2, 1), Seasonal Order: (0, 2, 2, 52), RMSE: 45.336517978558334
# Order: (3, 2, 1), Seasonal Order: (1, 0, 0, 52), RMSE: 10.063980625174178
# Order: (3, 2, 1), Seasonal Order: (1, 0, 1, 52), RMSE: 33.19323945208247
# Order: (3, 2, 1), Seasonal Order: (1, 0, 2, 52), RMSE: 11.49892961266916
# Order: (3, 2, 1), Seasonal Order: (1, 1, 0, 52), RMSE: 11.1005144643498
# Order: (3, 2, 1), Seasonal Order: (1, 1, 1, 52), RMSE: 8.660765007290362
# Order: (3, 2, 1), Seasonal Order: (1, 1, 2, 52), RMSE: 1173886.9527158528
# Order: (3, 2, 1), Seasonal Order: (1, 2, 0, 52), RMSE: 31.506779549801728
# Order: (3, 2, 1), Seasonal Order: (1, 2, 1, 52), RMSE: 343904.898064502
# Order: (3, 2, 1), Seasonal Order: (1, 2, 2, 52), RMSE: 45.336517978558334
# Order: (3, 2, 1), Seasonal Order: (2, 0, 0, 52), RMSE: 9.787447587306177
# Order: (3, 2, 1), Seasonal Order: (2, 0, 1, 52), RMSE: 32.92709211929292
# Order: (3, 2, 1), Seasonal Order: (2, 0, 2, 52), RMSE: 7.777573852523547
# Order: (3, 2, 1), Seasonal Order: (2, 1, 0, 52), RMSE: 2032094.6586963932
# Order: (3, 2, 1), Seasonal Order: (2, 1, 1, 52), RMSE: 1277790.3073102073
# Order: (3, 2, 1), Seasonal Order: (2, 1, 2, 52), RMSE: 2287482.956972715
# Order: (3, 2, 1), Seasonal Order: (2, 2, 0, 52), RMSE: 45.33651798592774
# Order: (3, 2, 1), Seasonal Order: (2, 2, 1, 52), RMSE: 45.33651798592774
# Order: (3, 2, 1), Seasonal Order: (2, 2, 2, 52), RMSE: 45.33651798592774
# Order: (3, 2, 2), Seasonal Order: (0, 0, 0, 52), RMSE: 6.522362837901863
# Order: (3, 2, 2), Seasonal Order: (0, 0, 1, 52), RMSE: 19.65781197811815
# Order: (3, 2, 2), Seasonal Order: (0, 0, 2, 52), RMSE: 10.31935087121062
# Order: (3, 2, 2), Seasonal Order: (0, 1, 0, 52), RMSE: 12.891631793766747
# Order: (3, 2, 2), Seasonal Order: (0, 1, 1, 52), RMSE: 4.800446087695488
# Order: (3, 2, 2), Seasonal Order: (0, 1, 2, 52), RMSE: 2321392.6887844587
# Order: (3, 2, 2), Seasonal Order: (0, 2, 0, 52), RMSE: 24.24015575936438
# Order: (3, 2, 2), Seasonal Order: (0, 2, 1, 52), RMSE: 31.498466256195048
# Order: (3, 2, 2), Seasonal Order: (0, 2, 2, 52), RMSE: 17926.244185101597
# Order: (3, 2, 2), Seasonal Order: (1, 0, 0, 52), RMSE: 8.089008337376344
# Order: (3, 2, 2), Seasonal Order: (1, 0, 1, 52), RMSE: 22.18862190766817
# Order: (3, 2, 2), Seasonal Order: (1, 0, 2, 52), RMSE: 14.312008514321018
# Order: (3, 2, 2), Seasonal Order: (1, 1, 0, 52), RMSE: 18.387087969224186
# Order: (3, 2, 2), Seasonal Order: (1, 1, 1, 52), RMSE: 13.041516817875907
# Order: (3, 2, 2), Seasonal Order: (1, 1, 2, 52), RMSE: 415398.70970909786
# Order: (3, 2, 2), Seasonal Order: (1, 2, 0, 52), RMSE: 31.758034458110053
# Order: (3, 2, 2), Seasonal Order: (1, 2, 1, 52), RMSE: 30.791218823016006
# Order: (3, 2, 2), Seasonal Order: (1, 2, 2, 52), RMSE: 17926.244185101597
# Order: (3, 2, 2), Seasonal Order: (2, 0, 0, 52), RMSE: 15.59837125026553
# Order: (3, 2, 2), Seasonal Order: (2, 0, 1, 52), RMSE: 22.3019258308275
# Order: (3, 2, 2), Seasonal Order: (2, 0, 2, 52), RMSE: 14.53474555691889
# Order: (3, 2, 2), Seasonal Order: (2, 1, 0, 52), RMSE: 18.035365889734884
# Order: (3, 2, 2), Seasonal Order: (2, 1, 1, 52), RMSE: 5616218.884658595
# Order: (3, 2, 2), Seasonal Order: (2, 1, 2, 52), RMSE: 3119297.1682455875
# Order: (3, 2, 2), Seasonal Order: (2, 2, 0, 52), RMSE: 17926.244185101597
# Order: (3, 2, 2), Seasonal Order: (2, 2, 1, 52), RMSE: 17926.244185101597
# Order: (3, 2, 2), Seasonal Order: (2, 2, 2, 52), RMSE: 17926.244185101597
# Order: (3, 2, 3), Seasonal Order: (0, 0, 0, 52), RMSE: 6.530320562953519
# Order: (3, 2, 3), Seasonal Order: (0, 0, 1, 52), RMSE: 139.08507118323305
# Order: (3, 2, 3), Seasonal Order: (0, 0, 2, 52), RMSE: 8.802039633109894
# Order: (3, 2, 3), Seasonal Order: (0, 1, 0, 52), RMSE: 9.548219515408608
# Order: (3, 2, 3), Seasonal Order: (0, 1, 1, 52), RMSE: 7.416861498272315
# Order: (3, 2, 3), Seasonal Order: (0, 1, 2, 52), RMSE: 2700094.675383402
# Order: (3, 2, 3), Seasonal Order: (0, 2, 0, 52), RMSE: 22.85979540238285
# Order: (3, 2, 3), Seasonal Order: (0, 2, 1, 52), RMSE: 28.052122271589
# Order: (3, 2, 3), Seasonal Order: (0, 2, 2, 52), RMSE: 31.648809443137065
# Order: (3, 2, 3), Seasonal Order: (1, 0, 0, 52), RMSE: 7.938455376509508
# Order: (3, 2, 3), Seasonal Order: (1, 0, 1, 52), RMSE: 202.69739121633367
# Order: (3, 2, 3), Seasonal Order: (1, 0, 2, 52), RMSE: 18.81680961301659
# Order: (3, 2, 3), Seasonal Order: (1, 1, 0, 52), RMSE: 23.270567510585305
# Order: (3, 2, 3), Seasonal Order: (1, 1, 1, 52), RMSE: 6.269242346500645
# Order: (3, 2, 3), Seasonal Order: (1, 1, 2, 52), RMSE: 2770223.863400362
# Order: (3, 2, 3), Seasonal Order: (1, 2, 0, 52), RMSE: 35.670054216833435
# Order: (3, 2, 3), Seasonal Order: (1, 2, 1, 52), RMSE: 58.74796816408396
# Order: (3, 2, 3), Seasonal Order: (1, 2, 2, 52), RMSE: 31.648809443137065
# Order: (3, 2, 3), Seasonal Order: (2, 0, 0, 52), RMSE: 9.906133345071124
# Order: (3, 2, 3), Seasonal Order: (2, 0, 1, 52), RMSE: 151.7516960671619
# Order: (3, 2, 3), Seasonal Order: (2, 0, 2, 52), RMSE: 9.556539316314836
# Order: (3, 2, 3), Seasonal Order: (2, 1, 0, 52), RMSE: 2944144.572520978
# Order: (3, 2, 3), Seasonal Order: (2, 1, 1, 52), RMSE: 19210700.402401723
# Order: (3, 2, 3), Seasonal Order: (2, 1, 2, 52), RMSE: 67215509.37905158
# Order: (3, 2, 3), Seasonal Order: (2, 2, 0, 52), RMSE: 31.631879449361218
# Order: (3, 2, 3), Seasonal Order: (2, 2, 1, 52), RMSE: 31.631879449361218
# Order: (3, 2, 3), Seasonal Order: (2, 2, 2, 52), RMSE: 31.648809443137065
# Order: (3, 2, 4), Seasonal Order: (0, 0, 0, 52), RMSE: 6.51967847650783
# Order: (3, 2, 4), Seasonal Order: (0, 0, 1, 52), RMSE: 460551265025246.56
# Order: (3, 2, 4), Seasonal Order: (0, 0, 2, 52), RMSE: 7.098208109230821
# Order: (3, 2, 4), Seasonal Order: (0, 1, 0, 52), RMSE: 9.5222787566974
# Order: (3, 2, 4), Seasonal Order: (0, 1, 1, 52), RMSE: 7.765629414476438
# Order: (3, 2, 4), Seasonal Order: (0, 1, 2, 52), RMSE: 18101159.59481102
# Order: (3, 2, 4), Seasonal Order: (0, 2, 0, 52), RMSE: 31.622732870519247
# Order: (3, 2, 4), Seasonal Order: (0, 2, 1, 52), RMSE: 34.122230039065435
# Order: (3, 2, 4), Seasonal Order: (0, 2, 2, 52), RMSE: 28.550553697951436
# Order: (3, 2, 4), Seasonal Order: (1, 0, 0, 52), RMSE: 7.491862972996914
# Order: (3, 2, 4), Seasonal Order: (1, 0, 1, 52), RMSE: 5.6059507050576776e+16
# Order: (3, 2, 4), Seasonal Order: (1, 0, 2, 52), RMSE: 12.760911544926708
# Order: (3, 2, 4), Seasonal Order: (1, 1, 0, 52), RMSE: 23.52417542248577
# Order: (3, 2, 4), Seasonal Order: (1, 1, 1, 52), RMSE: 17.71193404304329
# Order: (3, 2, 4), Seasonal Order: (1, 1, 2, 52), RMSE: 3756444.6961015277
# Order: (3, 2, 4), Seasonal Order: (1, 2, 0, 52), RMSE: 80.51354456887847
# Order: (3, 2, 4), Seasonal Order: (1, 2, 1, 52), RMSE: 1691.9565980384584
# Order: (3, 2, 4), Seasonal Order: (1, 2, 2, 52), RMSE: 28.550553697951436
# Order: (3, 2, 4), Seasonal Order: (2, 0, 0, 52), RMSE: 8.417955210153245
# Order: (3, 2, 4), Seasonal Order: (2, 0, 1, 52), RMSE: 821937176739.5267
# Order: (3, 2, 4), Seasonal Order: (2, 0, 2, 52), RMSE: 4.367130299833953
# Order: (3, 2, 4), Seasonal Order: (2, 1, 0, 52), RMSE: 2894138.4811990107
# Order: (3, 2, 4), Seasonal Order: (2, 1, 1, 52), RMSE: 317.23702057167236
# Order: (3, 2, 4), Seasonal Order: (2, 1, 2, 52), RMSE: 1257471.7536354612
# Order: (3, 2, 4), Seasonal Order: (2, 2, 0, 52), RMSE: 28.490772744084907
# Order: (3, 2, 4), Seasonal Order: (2, 2, 1, 52), RMSE: 28.490772744084907
# Order: (3, 2, 4), Seasonal Order: (2, 2, 2, 52), RMSE: 28.550553697951436

# %%
#Buscar en el dataset results para buscar los mejores hiperparámetros
if ITERATE:
    best_rmse = float('inf')
    best_pdq = None
    best_seasonal_pdq = None
    
    order_array = []
    seasonal_order_array= []
    rmse_array = []
    
    for result in results:
        order = result[0]
        seasonal_order = result[1]
        rmse = result[2]
        
        order_array.append(order)
        seasonal_order_array.append(seasonal_order)
        rmse_array.append(rmse)
    
        if rmse < best_rmse:
            best_pdq = order
            best_seasonal_pdq = seasonal_order
            best_rmse = rmse
    
    print(best_pdq)
    print(best_seasonal_pdq)
    print(best_rmse)
    
    results_df = pd.DataFrame({
        'pdq': order_array, 
        'sea_pdq': seasonal_order_array,
        'rmse': rmse_array
        })

    #Exporta los resultados de la iteración a excel
    output_route = '../03 - Output/iterations/sarima_iterations' + '_' + str(rp) + str(rd) + str(rq) + '_' + str(rP) + str(rD) + str(rQ) + str(rS) + '.xlsx'
    results_df.to_excel(output_route)

#Si no se quiere iterar, emplea los mejores hiperparámetros encontrados
else:
    #Limitando no convergencia, resulaodo raro en previsión.
    best_pdq = (1, 1, 0)
    best_seasonal_pdq = (2, 1, 0, 52)
    best_rmse = 5.0907
# Out:
# (3, 2, 4)
# (2, 0, 2, 52)
# 4.367130299833953

# %% [markdown]
# ## Testeo de hiperparámetros

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import mean_squared_error
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Definimos y entrenamos el modelo SARIMA utilizando statsmodels
forecaster = SARIMAX(
    df_sarima_train['y'],
    order=best_pdq,
    seasonal_order=best_seasonal_pdq,
    trend=None,
    enforce_stationarity=False,
    enforce_invertibility=False
)

# Ajustamos el modelo con un máximo de 100 iteraciones
results = forecaster.fit(maxiter=1000)

# Predecimos los valores en el rango del conjunto de prueba
y_pred_sarima = results.get_forecast(steps=16).predicted_mean

# Convertimos los resultados a un DataFrame para el gráfico y cálculo de error
data = {
    'ds': df_sarima_test['ds'],
    'yhat': y_pred_sarima
}
y_pred_sarima = pd.DataFrame(data)

# Calculamos el RMSE
rmse_sarima = mean_squared_error(df_sarima_test['y'], y_pred_sarima['yhat']) ** 0.5
print('RMSE: ' + str(rmse_sarima))

# Visualización de los resultados
dims = (20, 7)
fig, ax = plt.subplots(figsize=dims)
ax.set_ylim(0, 50)
plt.xticks(rotation=90)
sns.lineplot(data=df_sarima_train, x='ds', y='y', color='blue', label='train-test data')
sns.lineplot(data=df_sarima_test, x='ds', y='y', color='blue')
sns.lineplot(data=y_pred_sarima, x='ds', y='yhat', color='green', label='SARIMA')
plt.show()
# Out:
# C:\Users\Usuario\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# RMSE: 4.367130299833953

# %%
#Preparar dataset de comparación
df_forecast_comparison_sarima = df_sarima_test.merge(y_pred_sarima, on= 'ds')
df_forecast_comparison_sarima['error'] =  df_forecast_comparison_sarima['y'] - df_forecast_comparison_sarima['yhat']
#Parece centrado en 0. Buena señal
df_forecast_comparison_sarima['error'].plot(kind = 'bar')
print('suma de errores: ' + str(df_forecast_comparison_sarima['error'].sum()))
# Out:
# suma de errores: 5.232543599841311

# %%
#Calcular métricas de error
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error
print ('RMSE SARIMA: ' + str(mean_squared_error(df_forecast_comparison_sarima['y'], df_forecast_comparison_sarima['yhat']) ** (1/2)))
print ('MAE SARIMA: ' + str(mean_absolute_error(df_forecast_comparison_sarima['y'], df_forecast_comparison_sarima['yhat'])))
print ('MAPE SARIMA: ' + str(mean_absolute_percentage_error(df_forecast_comparison_sarima['y'], df_forecast_comparison_sarima['yhat'])))
# Out:
# RMSE SARIMA: 4.367130299833953
# MAE SARIMA: 3.7788942181584755
# MAPE SARIMA: 0.18873463010519426

# %% [markdown]
# ## Predicción de valores futuros

# %%
future_dates = pd.date_range(start=fecha_max, periods=17, freq='W-MON')[1:]

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import mean_squared_error
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.dates as mdates

# Definimos la función para limitar los valores a cero
def limitar_cero(valor):
    return max(0, valor)

# Definimos y entrenamos el modelo SARIMA utilizando statsmodels
forecaster = SARIMAX(
    df_sarima['y'],
    order=best_pdq,
    seasonal_order=best_seasonal_pdq,
    trend = None,
    enforce_stationarity=False,
    enforce_invertibility=False
)

# Ajustamos el modelo
sarima_fit = forecaster.fit(maxiter=10000)

#AJUSTAR PREDICT!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

# Generamos fechas futuras y realizamos las predicciones para el horizonte deseado
y_pred_sarima = sarima_fit.predict(start=len(df_sarima), end=len(df_sarima) + 15)

# Convertimos los resultados a un DataFrame para el gráfico
data = {
    'ds': future_dates,  # Asegúrate de que future_dates está definido correctamente
    'yhat': y_pred_sarima
}
y_pred_sarima = pd.DataFrame(data)

# Aplicamos la función limitar_cero para evitar valores negativos
y_pred_sarima['yhat'] = y_pred_sarima['yhat'].apply(limitar_cero)

# Visualización de los resultados
dims = (20, 7)
fig, ax = plt.subplots(figsize=dims)
ax.set_ylim(0, 50)
plt.xticks(rotation=90)
sns.lineplot(data=df_sarima, x='ds', y='y', color='blue', label='Histórico')
sns.lineplot(data=y_pred_sarima, x='ds', y='yhat', color='green', label='Predicción SARIMA')

# Configuración de los ejes para mostrar solo los meses
ax.xaxis.set_major_locator(mdates.MonthLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %Y'))

plt.show()
# Out:
# C:\Users\Usuario\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'

# %%
y_pred_sarima.to_excel('./predictions/y_pred_sarima.xlsx')

# %%
if ITERATE == True:
    
    from pmdarima import auto_arima
    from sktime.forecasting.sarimax import SARIMAX
    from sktime.forecasting.base import ForecastingHorizon
    import matplotlib.dates as mdates
    import pandas as pd
    import seaborn as sns
    import matplotlib.pyplot as plt
    
    # Encuentra los mejores parámetros automáticamente
    auto_model = auto_arima(df_sarima['y'], seasonal=True, m=52, trace=True,  # m=12 si los datos son mensuales, ajusta según tu frecuencia
                            error_action='ignore', suppress_warnings=True, stepwise=True)
    
    # Extrae los mejores órdenes
    best_pdq = auto_model.order
    best_seasonal_pdq = auto_model.seasonal_order
    
    # Define el forecaster con los parámetros encontrados automáticamente
    forecaster = SARIMAX(order=best_pdq, trend=None, seasonal_order=best_seasonal_pdq, enforce_stationarity=False, enforce_invertibility=False)
    
    # Ajusta el modelo
    forecaster.fit(df_sarima['y'])  
    
    # Genera las fechas futuras y el horizonte de predicción
    fh = ForecastingHorizon(pd.RangeIndex(start=len(df_sarima), stop=len(df_sarima) + 16), is_relative=False)
    y_pred_sarima = forecaster.predict(fh=fh)  
    
    # Crear un DataFrame con los resultados
    data = {
        'ds': future_dates,
        'yhat': y_pred_sarima
    }
    y_pred_sarima = pd.DataFrame(data)
    
    # Aplicar la función de límite a las predicciones
    y_pred_sarima['yhat'] = y_pred_sarima['yhat'].apply(limitar_cero)
    
    # Gráfico de los resultados
    dims = (20, 7)
    fig, ax = plt.subplots(figsize=dims)
    ax.set_ylim(0, 50)
    plt.xticks(rotation=90)
    sns.lineplot(data=df_sarima, x='ds', y='y', color='blue', label="Actual")
    sns.lineplot(data=y_pred_sarima, x='ds', y='yhat', color='green', label="Predicted")
    
    ax.xaxis.set_major_locator(mdates.MonthLocator())
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %Y'))
    
    plt.show()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[52] intercept   : AIC=inf, Time=4.15 sec
#  ARIMA(0,1,0)(0,0,0)[52] intercept   : AIC=1399.575, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[52] intercept   : AIC=1329.729, Time=0.43 sec
#  ARIMA(0,1,1)(0,0,1)[52] intercept   : AIC=1319.155, Time=0.47 sec
#  ARIMA(0,1,0)(0,0,0)[52]             : AIC=1397.581, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[52] intercept   : AIC=1350.562, Time=0.03 sec
#  ARIMA(0,1,1)(1,0,1)[52] intercept   : AIC=inf, Time=2.31 sec
#  ARIMA(0,1,1)(0,0,2)[52] intercept   : AIC=inf, Time=4.84 sec
#  ARIMA(0,1,1)(1,0,0)[52] intercept   : AIC=1297.784, Time=1.31 sec
#  ARIMA(0,1,1)(2,0,0)[52] intercept   : AIC=1287.430, Time=7.00 sec
#  ARIMA(0,1,1)(2,0,1)[52] intercept   : AIC=inf, Time=15.05 sec
#  ARIMA(0,1,0)(2,0,0)[52] intercept   : AIC=inf, Time=3.04 sec
#  ARIMA(1,1,1)(2,0,0)[52] intercept   : AIC=inf, Time=16.74 sec
#  ARIMA(0,1,2)(2,0,0)[52] intercept   : AIC=1283.250, Time=7.77 sec
#  ARIMA(0,1,2)(1,0,0)[52] intercept   : AIC=inf, Time=2.66 sec
#  ARIMA(0,1,2)(2,0,1)[52] intercept   : AIC=inf, Time=16.46 sec
#  ARIMA(0,1,2)(1,0,1)[52] intercept   : AIC=inf, Time=2.13 sec
#  ARIMA(1,1,2)(2,0,0)[52] intercept   : AIC=inf, Time=17.68 sec
#  ARIMA(0,1,3)(2,0,0)[52] intercept   : AIC=1281.577, Time=10.03 sec
#  ARIMA(0,1,3)(1,0,0)[52] intercept   : AIC=inf, Time=3.68 sec
#  ARIMA(0,1,3)(2,0,1)[52] intercept   : AIC=inf, Time=18.97 sec
#  ARIMA(0,1,3)(1,0,1)[52] intercept   : AIC=inf, Time=4.85 sec
#  ARIMA(1,1,3)(2,0,0)[52] intercept   : AIC=inf, Time=26.39 sec
#  ARIMA(0,1,4)(2,0,0)[52] intercept   : AIC=inf, Time=21.17 sec
#  ARIMA(1,1,4)(2,0,0)[52] intercept   : AIC=1285.290, Time=19.75 sec
#  ARIMA(0,1,3)(2,0,0)[52]             : AIC=1280.245, Time=6.37 sec
#  ARIMA(0,1,3)(1,0,0)[52]             : AIC=1291.482, Time=1.18 sec
#  ARIMA(0,1,3)(2,0,1)[52]             : AIC=inf, Time=25.71 sec
#  ARIMA(0,1,3)(1,0,1)[52]             : AIC=inf, Time=5.72 sec
#  ARIMA(0,1,2)(2,0,0)[52]             : AIC=1281.660, Time=4.45 sec
#  ARIMA(1,1,3)(2,0,0)[52]             : AIC=1281.533, Time=10.66 sec
#  ARIMA(0,1,4)(2,0,0)[52]             : AIC=1281.426, Time=7.70 sec
#  ARIMA(1,1,2)(2,0,0)[52]             : AIC=1279.763, Time=9.08 sec
#  ARIMA(1,1,2)(1,0,0)[52]             : AIC=1289.871, Time=1.40 sec
#  ARIMA(1,1,2)(2,0,1)[52]             : AIC=inf, Time=19.21 sec
#  ARIMA(1,1,2)(1,0,1)[52]             : AIC=inf, Time=5.04 sec
#  ARIMA(1,1,1)(2,0,0)[52]             : AIC=1279.383, Time=5.24 sec
#  ARIMA(1,1,1)(1,0,0)[52]             : AIC=1289.737, Time=0.99 sec
#  ARIMA(1,1,1)(2,0,1)[52]             : AIC=inf, Time=15.65 sec
#  ARIMA(1,1,1)(1,0,1)[52]             : AIC=inf, Time=2.74 sec
#  ARIMA(0,1,1)(2,0,0)[52]             : AIC=1285.578, Time=3.81 sec
#  ARIMA(1,1,0)(2,0,0)[52]             : AIC=inf, Time=2.64 sec
#  ARIMA(2,1,1)(2,0,0)[52]             : AIC=1279.571, Time=7.54 sec
#  ARIMA(0,1,0)(2,0,0)[52]             : AIC=inf, Time=2.90 sec
#  ARIMA(2,1,0)(2,0,0)[52]             : AIC=inf, Time=3.35 sec
#  ARIMA(2,1,2)(2,0,0)[52]             : AIC=1281.764, Time=10.72 sec
#
# Best model:  ARIMA(1,1,1)(2,0,0)[52]
# Total fit time: 359.366 seconds
